# %% [markdown]
# # 340 : Qualitative analysis using M3

# %%
import os, sys
from pathlib import Path

ENV_IS_GOOGLE_COLAB = True if 'google.colab' in str(get_ipython()) else False
os.environ["ENV_IS_GOOGLE_COLAB"] = str(ENV_IS_GOOGLE_COLAB)

if ENV_IS_GOOGLE_COLAB:
  from google.colab import drive
  mountpoint = Path("/content/drive")
  drive.mount(str(mountpoint)) # Mount gdrive to BASE
  base = mountpoint / "MyDrive/article_icdar_2023" # Adapt this to your situation
  sys.path.append(str(base)) # Add BASE to Python Path
  BASE = Path(base).resolve() # Make BASE absolute
  DATASETS =  BASE / "dataset_ICDAR"
  OUT_BASE = BASE / "res_ICDAR/method_3"
else:
  BASE = Path().resolve() # Directory of this approach
  #Adapt this to your situation
  DATASETS = Path('../dataset_ICDAR').resolve() #Where your data are located befor Dataset object creation
  DATA_BASE = Path('../res_ICDAR/method_2').resolve()
  OUT_BASE = Path('../res_ICDAR/method_3').resolve() #Where you save the results of this notebook

print(sys.path)
print(BASE)
print(DATASETS)
print(OUT_BASE)
# Out:
# ['/lrde/home2/stual/stage_DAS/m3_hierarchical_ner', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/lrde/home2/stual/.venv/python_3_9/lib/python3.10/site-packages']
# /lrde/home2/stual/stage_DAS/m3_hierarchical_ner
# /work/stual/dataset_ICDAR
# /work/stual/res_ICDAR/method_3

# %% [markdown]
# ## Model

# %% [markdown]
# Choose a fine-tuned model to perform qualitative analysis. Load models from the HuggingFace.

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
models = ['m3_hierarchical_ner_ref_cmbert_io',
 'm3_hierarchical_ner_ref_ptrn_cmbert_io',
 'm3_hierarchical_ner_ref_cmbert_iob2',
 'm3_hierarchical_ner_ref_ptrn_cmbert_iob2',
 'm3_hierarchical_ner_ocr_cmbert_io',
 'm3_hierarchical_ner_ocr_ptrn_cmbert_io',
 'm3_hierarchical_ner_ocr_cmbert_iob2',
 'm3_hierarchical_ner_ocr_ptrn_cmbert_iob2',
]

# %%
model_name = widgets.RadioButtons(
            options=models,
            layout={'width': 'max-content'}
        )
model_name
# Out:
# RadioButtons(layout=Layout(width='max-content'), options=('m3_hierarchical_ner_ref_cmbert_io', 'm3_hierarchica…

# %%
MODEL = model_name.value
FORMAT = 'IO'

if 'ref' in MODEL:
    SET = "ref"
elif 'ocr' in MODEL:
    SET = "ocr"

if 'ptrn' in MODEL:
    MODEL_TYPE = 'pretrained_camembert_ner'
else:
    MODEL_TYPE = 'camembert_ner'
    
if 'm3_hierarchical_ner_ref_cmbert_io' in MODEL:
    DATASET = 'm2m3_qualitative_analysis_ref_cmbert_io'
elif 'm3_hierarchical_ner_ref_ptrn_cmbert_io' in MODEL:
    DATASET = 'm2m3_qualitative_analysis_ref_ptrn_cmbert_io'
elif 'm3_hierarchical_ner_ref_cmbert_iob2' in MODEL:
    DATASET = 'm2m3_qualitative_analysis_ref_cmbert_iob2'
elif 'm3_hierarchical_ner_ref_ptrn_cmbert_iob2' in MODEL:
    DATASET = 'm2m3_qualitative_analysis_ref_ptrn_cmbert_iob2'
elif 'm3_hierarchical_ner_ocr_cmbert_io' in MODEL:
    DATASET = 'm2m3_qualitative_analysis_ocr_cmbert_io'
elif 'm3_hierarchical_ner_ocr_ptrn_cmbert_io' in MODEL:
    DATASET = 'm2m3_qualitative_analysis_ocr_ptrn_cmbert_io'
elif 'm3_hierarchical_ner_ocr_cmbert_iob2' in MODEL:
    DATASET = 'm2m3_qualitative_analysis_ocr_cmbert_iob2'
elif 'm2_joint_label_ocr_ptrn_cmbert_iob2' in MODEL:
    DATASET = 'm3_hierarchical_ner_ocr_ptrn_cmbert_iob2'

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Gold

# %%
import os
from pathlib import Path
from config import logger
from datasets import load_dataset

TRAINSETS_SIZES = [6084] #To train only on the biggest dataset
train_dev_test = load_dataset('nlpso/' + DATASET)
test = train_dev_test["test"]
test
# Out:
# Using custom data configuration nlpso--m2m3_qualitative_analysis_ref_cmbert_io-b04ead085a50a8db
# Found cached dataset parquet (/lrde/home2/stual/.cache/huggingface/datasets/nlpso___parquet/nlpso--m2m3_qualitative_analysis_ref_cmbert_io-b04ead085a50a8db/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Dataset({
#     features: ['tokens', 'ner_tags', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 1685
# })

# %% [markdown]
# ### Non-structured entries

# %%
PATH = f"{DATASETS}/qualitative_analysis/test_entries_{SET}.txt"
with open(PATH, 'r',encoding='utf8') as ex:
    lines = ex.read()
    lines = lines.split('\n')
len(lines)
# Out:
# List of datasets and non-classified examples to test :
# m2-camembert-ner-pero-io/huggingface_1685
# m2-camembert-ner-pero-io/test_examples_io.txt
# m2-camembert-ner-pero-iob2/huggingface_1685
# m2-camembert-ner-pero-iob2/test_examples_iob2.txt
# m2-camembert-ner-ref-io/huggingface_1685
# m2-camembert-ner-ref-io/test_examples_io.txt
# m2-camembert-ner-ref-iob2/huggingface_1685
# m2-camembert-ner-ref-iob2/test_examples_iob2.txt

# %% [markdown]
# ## Use model on entries

# %%
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification, TokenClassificationPipeline

LIMIT = 100

tokenizer = AutoTokenizer.from_pretrained('nlpso/' + MODEL) #Param : tokenizer du modele souhaité
model = AutoModelForTokenClassification.from_pretrained('nlpso/' + MODEL) #Modèle choisi

#Classification des entités
nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy=None, use_fast=True)
# Out:
# 2023-02-09 14:49:17.690591: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-09 14:49:20.768701: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-09 14:49:20.768893: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-09 14:49:20.768916: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from xmlize_util import get_NER_tags
if FORMAT == "IOB2":
    from hierarchicalNER.util_IOB2 import word_tokens_from_nested_xml_iob2
else:
    from hierarchicalNER.util_IO import word_tokens_from_nested_xml
from xmlize_util import get_NER_tags, xmlize_multilevel

stats = []
k = 0 
errors_count = 0
errors = []
for i in range(len(lines)):
    res = nlp(lines[i][:-1])
    preds_tokens, preds_tags = [],[]

    for e in res:
        preds_tokens.append(e["word"])
        preds_tags.append(e['entity'])
    levels, num_levels = get_NER_tags(lines[i][:-1],res)
    xml = xmlize_multilevel(levels,num_levels)

    try:
        assert len(test[i]["tokens"]) == len(preds_tokens)
        assert len(test[i]["ner_tags"]) == len(preds_tags)
        stats.append([k,lines[i][:-1],xml,test[i]["tokens"],test[i]["ner_tags"],preds_tokens,preds_tags])
    except:
        errors_count += 1
        print("NUM " + str(k))
        print(lines[i][:-1])
    k += 1
    
#print(errors_count)
# Out:
# Tree positions of all the leaves{'O+O': (0, 0), 'I-PER+O': (1, 0), 'I-PER+i_TITREH': (1, 1), 'I-ACT+O': (2, 0), 'I-DESC+O': (3, 0), 'I-DESC+i_ACT': (3, 1), 'I-DESC+i_TITREP': (3, 2), 'I-SPAT+O': (4, 0), 'I-SPAT+i_LOC': (4, 1), 'I-SPAT+i_CARDINAL': (4, 2), 'I-SPAT+i_FT': (4, 3), 'I-TITRE+O': (5, 0)} #1
# Num of classes : 12
# [nltk_data] Downloading package punkt to
# [nltk_data]     /lrde/home2/stual/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#   label  start  end                          span
# 0   PER      0    7                       Arnoult
# 1   ACT      7   35  , fabr. de moules de boutons
# 2     O     35   36                             ,
# 3  SPAT     36   61      r. dela Chanverrerie, 8
# 4   ACT     61   62                             .
#       label  start  end                                 span
# 0         O      0   35  Arnoult, fabr. de moules de boutons
# 1         O     35   36                                    ,
# 2       LOC     36   58                r. dela Chanverrerie
# 3         O     58   59                                    ,
# 4  CARDINAL     59   61                                    8
# 5         O     61   62                                    .
#   label  start  end              span
# 0   PER      0    6            Bayard
# 1     O      6    7                 ,
# 2  SPAT      7   23   r. du Roule, 21
# 3   ACT     23   24                 .
#       label  start  end          span
# 0         O      0    6        Bayard
# 1         O      6    7             ,
# 2       LOC      7   19   r. du Roule
# 3         O     19   20             ,
# 4  CARDINAL     20   23            21
# 5         O     23   24             .
#   label  start  end               span
# 0   PER      0    7            Berchet
# 1     O      7    8                  ,
# 2  SPAT      8   25   r. du Temple, 71
# 3   ACT     25   26                  .
#       label  start  end           span
# 0         O      0    7        Berchet
# 1         O      7    8              ,
# 2       LOC      8   21   r. du Temple
# 3         O     21   22              ,
# 4  CARDINAL     22   25             71
# 5         O     25   26              .
#   label  start  end                                span
# 0   PER      0    7                             Bouchet
# 1   ACT      7   14                             , fabr.
# 2     O     14   15                                   ,
# 3  SPAT     15   49   r. du Cimetière-Saint-Nicolas, 5
# 4   ACT     49   50                                   .
#       label  start  end                             span
# 0         O      0   14                   Bouchet, fabr.
# 1         O     14   15                                ,
# 2       LOC     15   46   r. du Cimetière-Saint-Nicolas
# 3         O     46   47                                ,
# 4  CARDINAL     47   49                                5
# 5         O     49   50                                .
#   label  start  end                                               span
# 0   PER      0   16                                   Chardin et comp.
# 1  DESC     16   82  , fabr. de boutons demétal artimomantico, par...
# 2     O     82   83                                                  ,
# 3  DESC     83   85                                                  à
# 4  SPAT     85   95                                          Vaugirard
# 5  DESC     95   96                                                  .
#   label  start  end                                       span
# 0     O      0   16                           Chardin et comp.
# 1   ACT     16   57  , fabr. de boutons demétal artimomantico
# 2     O     57   82                  , par brevet din-vention
# 3     O     82   83                                          ,
# 4     O     83   85                                          à
# 5   LOC     85   95                                  Vaugirard
# 6     O     95   96                                          .
#   label  start  end                        span
# 0   PER      0    9                   Chevalier
# 1   ACT      9   35  , ſabr. de boutons de soie
# 2     O     35   36                           ,
# 3  SPAT     36   53            rueS.-Denis, 41
# 4   ACT     53   54                           .
#       label  start  end                                 span
# 0         O      0   35  Chevalier, ſabr. de boutons de soie
# 1         O     35   36                                    ,
# 2       LOC     36   49                         rueS.-Denis
# 3         O     49   50                                    ,
# 4  CARDINAL     50   53                                   41
# 5         O     53   54                                    .
#   label  start  end                 span
# 0   PER      0    4                 Inge
# 1   ACT      4   11              ,fabr.
# 2     O     11   12                    ,
# 3  SPAT     12   31   r. Pastourelle, 18
# 4   ACT     31   32                    .
#       label  start  end             span
# 0         O      0   11      Inge,fabr.
# 1         O     11   12                ,
# 2       LOC     12   27   r. Pastourelle
# 3         O     27   28                ,
# 4  CARDINAL     28   31               18
# 5         O     31   32                .
#   label  start  end                              span
# 0   PER      0   32  Josse (Ch.) et Fr. Duquesne ainé
# 1   ACT     32   56          , fabr.el quincailliers
# 2     O     56   57                                 ,
# 3  SPAT     57   78             r. Neuve-S.-Merry, 44
# 4   ACT     78   79                                 .
#       label  start  end                                               span
# 0         O      0   56  Josse (Ch.) et Fr. Duquesne ainé, fabr.el qui...
# 1         O     56   57                                                  ,
# 2       LOC     57   74                                  r. Neuve-S.-Merry
# 3         O     74   75                                                  ,
# 4  CARDINAL     75   78                                                 44
# 5         O     78   79                                                  .
#   label  start  end                        span
# 0   PER      0    7                     Joubert
# 1     O      7    8                           ,
# 2  SPAT      8   34   passage de la Marmite. 1.
#       label  start  end                    span
# 0         O      0    7                 Joubert
# 1         O      7    8                       ,
# 2       LOC      8   30   passage de la Marmite
# 3         O     30   31                       .
# 4  CARDINAL     31   34                      1.
#   label  start  end                  span
# 0   PER      0   20  Lalonël-Puissan,L.)
# 1  SPAT     20   39    r. Quincampeix, 33
# 2   PER     39   40                     .
#       label  start  end                  span
# 0         O      0   20  Lalonël-Puissan,L.)
# 1       LOC     20   35        r. Quincampeix
# 2         O     35   36                     ,
# 3  CARDINAL     36   39                    33
# 4         O     39   40                     .
#   label  start  end                              span
# 0   PER      0   18                Lambriquet, (Aug.)
# 1   ACT     18   26                           fabric.
# 2     O     26   27                                 ,
# 3  SPAT     27   59   rue de laGrande-Truanderie, 52
# 4   ACT     59   60                                 .
#       label  start  end                          span
# 0         O      0   26    Lambriquet, (Aug.) fabric.
# 1         O     26   27                             ,
# 2       LOC     27   55   rue de laGrande-Truanderie
# 3         O     55   56                             ,
# 4  CARDINAL     56   59                            52
# 5         O     59   60                             .
#   label  start  end                               span
# 0   PER      0    8                           Maillard
# 1   ACT      8   41  , boutons plaqués et autresmodes
# 2     O     41   42                                  ,
# 3  SPAT     42   61                 r. S.-Martin, 222.
# 4     O     61   64                                de
#       label  start  end                                       span
# 0         O      0   41  Maillard, boutons plaqués et autresmodes
# 1         O     41   42                                          ,
# 2       LOC     42   55                               r. S.-Martin
# 3         O     55   56                                          ,
# 4  CARDINAL     56   61                                       222.
# 5         O     61   64                                        de
#   label  start  end                                  span
# 0   PER      0    7                               Mionnet
# 1   ACT      7   43  , ſabr. de S. M. Impériale clRoyale
# 2     O     43   44                                     ,
# 3  SPAT     44   66                 r. Neuve-S.-Martin, 5
# 4   ACT     66   67                                     .
#       label  start  end                                         span
# 0         O      0   43  Mionnet, ſabr. de S. M. Impériale clRoyale
# 1         O     43   44                                            ,
# 2       LOC     44   63                           r. Neuve-S.-Martin
# 3         O     63   64                                            ,
# 4  CARDINAL     64   66                                            5
# 5         O     66   67                                            .
#   label  start  end                                 span
# 0   PER      0    7                              Molière
# 1   ACT      7   42  , fabric., et paillons or el argent
# 2     O     42   43                                    ,
# 3  SPAT     43   64                r. de la Monnaie, 19
# 4   ACT     64   65                                    .
#       label  start  end                                        span
# 0         O      0   42  Molière, fabric., et paillons or el argent
# 1         O     42   43                                           ,
# 2       LOC     43   60                           r. de la Monnaie
# 3         O     60   61                                           ,
# 4  CARDINAL     61   64                                          19
# 5         O     64   65                                           .
#   label  start  end                            span
# 0   PER      0   20            Christofle, (Isidor)
# 1   ACT     20   50   fabr. de boutons defantaisie
# 2     O     50   51                               ,
# 3  SPAT     51   68                r. du Temple, 22
# 4   ACT     68   69                               .
#       label  start  end                                               span
# 0         O      0   50  Christofle, (Isidor) fabr. de boutons defanta...
# 1         O     50   51                                                  ,
# 2       LOC     51   64                                       r. du Temple
# 3         O     64   65                                                  ,
# 4  CARDINAL     65   68                                                 22
# 5         O     68   69                                                  .
#   label  start  end                  span
# 0   PER      0    7               Coquart
# 1   ACT      7   14               , fabr.
# 2     O     14   15                     ,
# 3  SPAT     15   35   r. Barre-du-Bec, 17
# 4   ACT     35   36                     .
#       label  start  end              span
# 0         O      0   14    Coquart, fabr.
# 1         O     14   15                 ,
# 2       LOC     15   31   r. Barre-du-Bec
# 3         O     31   32                 ,
# 4  CARDINAL     32   35                17
# 5         O     35   36                 .
#   label  start  end                          span
# 0   PER      0    6                        Dallof
# 1     O      6    7                             ,
# 2  SPAT      7   35   r. du Chevalier-du-Guet, 1.
#       label  start  end                      span
# 0         O      0    6                    Dallof
# 1         O      6    7                         ,
# 2       LOC      7   31   r. du Chevalier-du-Guet
# 3         O     31   32                         ,
# 4  CARDINAL     32   35                        1.
#   label  start  end                     span
# 0   PER      0    5                    Damin
# 1     O      5    6                        ,
# 2  SPAT      6   29   quai de la Monnaie, 25
# 3   ACT     29   30                        .
#       label  start  end                 span
# 0         O      0    5                Damin
# 1         O      5    6                    ,
# 2       LOC      6   25   quai de la Monnaie
# 3         O     25   26                    ,
# 4  CARDINAL     26   29                   25
# 5         O     29   30                    .
#   label  start  end                                  span
# 0   PER      0   16                      Delaporte frères
# 1   ACT     16   50    , march. et ſabric. entous genres
# 2     O     50   51                                     ,
# 3  SPAT     51   87   rue des Deux-Portes-S.-Sauveur, 18
# 4   ACT     87   88                                     .
#       label  start  end                                               span
# 0         O      0   50  Delaporte frères, march. et ſabric. entous ge...
# 1         O     50   51                                                  ,
# 2       LOC     51   83                    rue des Deux-Portes-S.-Sauveur
# 3         O     83   84                                                  ,
# 4  CARDINAL     84   87                                                 18
# 5         O     87   88                                                  .
#   label  start  end                 span
# 0   PER      0    7              Mousset
# 1   ACT      7   14              , fabr.
# 2     O     14   15                    ,
# 3  SPAT     15   34   r. du Vert-bois, 8
# 4   ACT     34   35                    .
#       label  start  end              span
# 0         O      0   14    Mousset, fabr.
# 1         O     14   15                 ,
# 2       LOC     15   31   r. du Vert-bois
# 3         O     31   32                 ,
# 4  CARDINAL     32   34                 8
# 5         O     34   35                 .
#   label  start  end             span
# 0   PER      0    6           Pépin,
# 1   ACT      6    8                (
# 2   PER      8    9                M
# 3   ACT      9   11               ad
# 4   PER     11   13               .)
# 5  SPAT     13   28   r. Marceau, 24
# 6   ACT     28   29                .
#       label  start  end           span
# 0         O      0   13  Pépin, (Mad.)
# 1       LOC     13   24     r. Marceau
# 2         O     24   25              ,
# 3  CARDINAL     25   28             24
# 4         O     28   29              .
#   label  start  end               span
# 0   PER      0    8           Pilgrain
# 1     O      8    9                  ,
# 2  SPAT      9   26   r. S.-Honoré, 25
# 3   ACT     26   27                  .
#       label  start  end           span
# 0         O      0    8       Pilgrain
# 1         O      8    9              ,
# 2       LOC      9   22   r. S.-Honoré
# 3         O     22   23              ,
# 4  CARDINAL     23   26             25
# 5         O     26   27              .
#   label  start  end                      span
# 0   PER      0    8                  Poncelet
# 1   ACT      8   15                   , fabr.
# 2     O     15   16                         ,
# 3  SPAT     16   36       rue S.-Martin, 183,
# 4     O     36   39                        ct
# 5  SPAT     39   63  rue du Grand-Hurleur, 3
# 6   ACT     63   64                         .
#       label  start  end                   span
# 0         O      0   15        Poncelet, fabr.
# 1         O     15   16                      ,
# 2       LOC     16   30          rue S.-Martin
# 3         O     30   31                      ,
# 4  CARDINAL     31   36                   183,
# 5         O     36   39                     ct
# 6       LOC     39   60  rue du Grand-Hurleur
# 7         O     60   61                      ,
# 8  CARDINAL     61   63                      3
# 9         O     63   64                      .
#   label  start  end                        span
# 0   PER      0   24    Pothier, (Alex.-Mathias)
# 1   ACT     24   48     fabr, boutonsduniforme
# 2     O     48   49                           ,
# 3  SPAT     49   67           r. S.-Martin, 104
# 4     O     67   68                           ,
# 5  SPAT     68   94   passagede la Réunion, 10
# 6   ACT     94   95                           .
#       label  start  end                                              span
# 0         O      0   48  Pothier, (Alex.-Mathias) fabr, boutonsduniforme
# 1         O     48   49                                                 ,
# 2       LOC     49   62                                      r. S.-Martin
# 3         O     62   63                                                 ,
# 4  CARDINAL     63   67                                               104
# 5         O     67   68                                                 ,
# 6       LOC     68   90                             passagede la Réunion
# 7         O     90   91                                                 ,
# 8  CARDINAL     91   94                                                10
# 9         O     94   95                                                 .
#   label  start  end               span
# 0   PER      0    8           Demonjay
# 1   ACT      8   21      , et frangier
# 2     O     21   22                  ,
# 3  SPAT     22   39   r. S.-Honoré, 34
# 4   ACT     39   40                  .
#       label  start  end                   span
# 0         O      0   21  Demonjay, et frangier
# 1         O     21   22                      ,
# 2       LOC     22   35           r. S.-Honoré
# 3         O     35   36                      ,
# 4  CARDINAL     36   39                     34
# 5         O     39   40                      .
#   label  start  end                 span
# 0   PER      0   10           Desmanches
# 1   ACT     10   17              , fabr.
# 2     O     17   18                    ,
# 3  SPAT     18   37   cul-de-sac Basfour
# 4   ACT     37   38                    .
#   label  start  end                 span
# 0     O      0   17    Desmanches, fabr.
# 1     O     17   18                    ,
# 2   LOC     18   37   cul-de-sac Basfour
# 3     O     37   38                    .
#   label  start  end                    span
# 0   PER      0    9               Desvertus
# 1     O      9   10                       ,
# 2  SPAT     10   32   passage de la Marmite
# 3   ACT     32   33                       .
#   label  start  end                    span
# 0     O      0    9               Desvertus
# 1     O      9   10                       ,
# 2   LOC     10   32   passage de la Marmite
# 3     O     32   33                       .
#   label  start  end                span
# 0   PER      0    7             Dillais
# 1     O      7    8                   ,
# 2  SPAT      8   26   r. S.-Honoré, 114
# 3   ACT     26   27                   .
#       label  start  end           span
# 0         O      0    7        Dillais
# 1         O      7    8              ,
# 2       LOC      8   21   r. S.-Honoré
# 3         O     21   22              ,
# 4  CARDINAL     22   26            114
# 5         O     26   27              .
#   label  start  end             span
# 0   PER      0    6           Dubray
# 1   ACT      6   13          , fabr.
# 2     O     13   14                ,
# 3  SPAT     14   29   r. Verderel, 3
# 4   ACT     29   30                .
#       label  start  end           span
# 0         O      0   13  Dubray, fabr.
# 1         O     13   14              ,
# 2       LOC     14   26    r. Verderel
# 3         O     26   27              ,
# 4  CARDINAL     27   29              3
# 5         O     29   30              .
#   label  start  end                span
# 0   PER      0   10          Dubuisson,
# 1   ACT     10   12                  (
# 2   PER     12   13                   M
# 3   ACT     13   15                  ad
# 4   PER     15   17                  .)
# 5  SPAT     17   35   r. S.-Severin, 30
# 6   ACT     35   36                   .
#       label  start  end               span
# 0         O      0   17  Dubuisson,(Mad.)
# 1       LOC     17   31      r. S.-Severin
# 2         O     31   32                  ,
# 3  CARDINAL     32   35                 30
# 4         O     35   36                  .
#   label  start  end               span
# 0   PER      0    7            Duhamel
# 1     O      7    8                  ,
# 2  SPAT      8   25   r. S.-Honoré, 50
# 3   ACT     25   26                  .
#       label  start  end           span
# 0         O      0    7        Duhamel
# 1         O      7    8              ,
# 2       LOC      8   21   r. S.-Honoré
# 3         O     21   22              ,
# 4  CARDINAL     22   25             50
# 5         O     25   26              .
#   label  start  end                                            span
# 0   PER      0    8                                        Feuillet
# 1   ACT      8   54  , ſabric. de boutons d'uniformeen lous genres
# 2     O     54   55                                               ,
# 3  SPAT     55   77                           r. des Pet.-Champs, 2
# 4   ACT     77   78                                               .
#       label  start  end                                               span
# 0         O      0   54  Feuillet, ſabric. de boutons d'uniformeen lou...
# 1         O     54   55                                                  ,
# 2       LOC     55   74                                 r. des Pet.-Champs
# 3         O     74   75                                                  ,
# 4  CARDINAL     75   77                                                  2
# 5         O     77   78                                                  .
#   label  start  end               span
# 0   PER      0    8           Gravelin
# 1     O      8    9                  ,
# 2  SPAT      9   26   r. Tirecharpe, 8
# 3   ACT     26   27                  .
#       label  start  end            span
# 0         O      0    8        Gravelin
# 1         O      8    9               ,
# 2       LOC      9   23   r. Tirecharpe
# 3         O     23   24               ,
# 4  CARDINAL     24   26               8
# 5         O     26   27               .
#   label  start  end                                               span
# 0   PER      0   16                                   Héricée, (J.-L.)
# 1   ACT     16   98   fabric. pour la troupe;boutons en étain fond...
# 2     O     98   99                                                  ,
# 3  SPAT     99  119                                r. Bourg-l'Abbé, 52
# 4   ACT    119  120                                                  .
#       label  start  end                                               span
# 0         O      0   98  Héricée, (J.-L.) fabric. pour la troupe;bouto...
# 1         O     98   99                                                  ,
# 2       LOC     99  115                                    r. Bourg-l'Abbé
# 3         O    115  116                                                  ,
# 4  CARDINAL    116  119                                                 52
# 5         O    119  120                                                  .
#   label  start  end                                     span
# 0   PER      0    5                                    Hesse
# 1   ACT      5   44  , fabr. de boutons plaqués or etargent
# 2     O     44   45                                        ,
# 3  SPAT     45   68                   r. Michel-le-Comte, 14
# 4   ACT     68   69                                        .
#       label  start  end                                          span
# 0         O      0   44  Hesse, fabr. de boutons plaqués or etargent
# 1         O     44   45                                             ,
# 2       LOC     45   64                            r. Michel-le-Comte
# 3         O     64   65                                             ,
# 4  CARDINAL     65   68                                            14
# 5         O     68   69                                             .
#   label  start  end               span
# 0   PER      0    7            Houdier
# 1     O      7    8                  ,
# 2  SPAT      8   25   r. S.-Denis, 398
# 3   ACT     25   26                  .
#       label  start  end          span
# 0         O      0    7       Houdier
# 1         O      7    8             ,
# 2       LOC      8   20   r. S.-Denis
# 3         O     20   21             ,
# 4  CARDINAL     21   25           398
# 5         O     25   26             .
#   label  start  end                       span
# 0   PER      0    7                    Raffard
# 1     O      7    8                          ,
# 2  SPAT      8   33   r. de la Ferronnerie. 12
#       label  start  end                   span
# 0         O      0    7                Raffard
# 1         O      7    8                      ,
# 2       LOC      8   29   r. de la Ferronnerie
# 3         O     29   30                      .
# 4  CARDINAL     30   33                     12
#   label  start  end                    span
# 0   PER      0   21   Renand-Delset, (Mad.)
# 1   ACT     21   27                   fabr.
# 2     O     27   28                       ,
# 3  SPAT     28   50   rue de laMonnaie, 12
# 4   ACT     50   51                       .
#       label  start  end                         span
# 0         O      0   27  Renand-Delset, (Mad.) fabr.
# 1         O     27   28                            ,
# 2       LOC     28   46            rue de laMonnaie
# 3         O     46   47                            ,
# 4  CARDINAL     47   50                           12
# 5         O     50   51                            .
#   label  start  end                span
# 0   PER      0    7             Reynaud
# 1     O      7    8                   ,
# 2  SPAT      8   26   r. S.-Honoré, 167
# 3   ACT     26   27                   .
#       label  start  end           span
# 0         O      0    7        Reynaud
# 1         O      7    8              ,
# 2       LOC      8   21   r. S.-Honoré
# 3         O     21   22              ,
# 4  CARDINAL     22   26            167
# 5         O     26   27              .
#   label  start  end              span
# 0   PER      0    7           Reynaud
# 1     O      7    8                 ,
# 2  SPAT      8   24   r. Richelieu. 9
# 3   ACT     24   25                 .
#       label  start  end           span
# 0         O      0    7        Reynaud
# 1         O      7    8              ,
# 2       LOC      8   21   r. Richelieu
# 3         O     21   22              .
# 4  CARDINAL     22   24              9
# 5         O     24   25              .
#   label  start  end             span
# 0   PER      0    4             Rose
# 1   ACT      4   11          , fabr.
# 2     O     11   12                ,
# 3  SPAT     12   27   r. Greneta, 13
# 4   ACT     27   28                .
#       label  start  end         span
# 0         O      0   11  Rose, fabr.
# 1         O     11   12            ,
# 2       LOC     12   23   r. Greneta
# 3         O     23   24            ,
# 4  CARDINAL     24   27           13
# 5         O     27   28            .
#   label  start  end              span
# 0   PER      0    7           Roussel
# 1   ACT      7   14           , fabr.
# 2     O     14   15                 ,
# 3  SPAT     15   31   r. Frépillon, 5
# 4   ACT     31   32                 .
#       label  start  end            span
# 0         O      0   14  Roussel, fabr.
# 1         O     14   15               ,
# 2       LOC     15   28    r. Frépillon
# 3         O     28   29               ,
# 4  CARDINAL     29   31               5
# 5         O     31   32               .
#   label  start  end            span
# 0   PER      0    9       Rousselle
# 1   ACT      9   16         , fabr.
# 2     O     16   17               ,
# 3  SPAT     17   31   r. Chapon, 14
# 4   ACT     31   32               .
#       label  start  end              span
# 0         O      0   16  Rousselle, fabr.
# 1         O     16   17                 ,
# 2       LOC     17   27         r. Chapon
# 3         O     27   28                 ,
# 4  CARDINAL     28   31                14
# 5         O     31   32                 .
#   label  start  end                     span
# 0   PER      0    9                Roussilhe
# 1   ACT      9   16                  , ſabr.
# 2     O     16   17                        ,
# 3  SPAT     17   40   r. des Gravilliers. 25
# 4   ACT     40   41                        .
#       label  start  end                 span
# 0         O      0   16     Roussilhe, ſabr.
# 1         O     16   17                    ,
# 2       LOC     17   36   r. des Gravilliers
# 3         O     36   37                    .
# 4  CARDINAL     37   40                   25
# 5         O     40   41                    .
#   label  start  end                                        span
# 0   PER      0   14                              Saner, (Guil.)
# 1   ACT     14   56   fabr. pour les militutresde loutes armes
# 2     O     56   57                                           ,
# 3  SPAT     57   75                           r. S.-Laurent, 30
# 4   ACT     75   76                                           .
#       label  start  end                                               span
# 0         O      0   56  Saner, (Guil.) fabr. pour les militutresde lo...
# 1         O     56   57                                                  ,
# 2       LOC     57   71                                      r. S.-Laurent
# 3         O     71   72                                                  ,
# 4  CARDINAL     72   75                                                 30
# 5         O     75   76                                                  .
#   label  start  end                         span
# 0   PER      0    5                        Schey
# 1  DESC      5   25         , breveté dinvention
# 2     O     25   26                            ,
# 3  SPAT     26   53   r. des Petites-Ecuries, 5
# 4  DESC     53   54                            .
#       label  start  end                       span
# 0         O      0   25  Schey, breveté dinvention
# 1         O     25   26                          ,
# 2       LOC     26   50    r. des Petites-Ecuries
# 3         O     50   51                          ,
# 4  CARDINAL     51   53                          5
# 5         O     53   54                          .
#   label  start  end                      span
# 0   PER      0    6                    Schmit
# 1   ACT      6   13                   , fabr.
# 2     O     13   14                         ,
# 3  SPAT     14   38   r. des Petits-Champs. 4
# 4   ACT     38   39                         .
#       label  start  end                   span
# 0         O      0   13          Schmit, fabr.
# 1         O     13   14                      ,
# 2       LOC     14   35   r. des Petits-Champs
# 3         O     35   36                      .
# 4  CARDINAL     36   38                      4
# 5         O     38   39                      .
#   label  start  end                          span
# 0   PER      0    6                        Sornet
# 1   ACT      6   14                      , (Gab.)
# 2  SPAT     14   42   r. de la Ferronnerie, 6 bis
# 3   ACT     42   43                             .
#       label  start  end                   span
# 0         O      0   14         Sornet, (Gab.)
# 1       LOC     14   35   r. de la Ferronnerie
# 2         O     35   36                      ,
# 3  CARDINAL     36   42                  6 bis
# 4         O     42   43                      .
#   label  start  end                   span
# 0   PER      0    5                  Tardu
# 1   ACT      5   12                , ſabr.
# 2     O     12   13                      ,
# 3  SPAT     13   34   rue Sainl-Denis, 124
# 4     O     34   35                      ;
# 5  SPAT     35   50         courBatave, 3
# 6   ACT     50   51                      .
#       label  start  end              span
# 0         O      0   12      Tardu, ſabr.
# 1         O     12   13                 ,
# 2       LOC     13   29   rue Sainl-Denis
# 3         O     29   30                 ,
# 4  CARDINAL     30   34               124
# 5         O     34   35                 ;
# 6       LOC     35   47       courBatave
# 7         O     47   48                 ,
# 8  CARDINAL     48   50                 3
# 9         O     50   51                 .
#   label  start  end            span
# 0   PER      0   10      Trouillion
# 1   ACT     10   17         , fabr.
# 2     O     17   18               ,
# 3  SPAT     18   32   r. Chapon, 12
# 4   ACT     32   33               .
#       label  start  end               span
# 0         O      0   17  Trouillion, fabr.
# 1         O     17   18                  ,
# 2       LOC     18   28          r. Chapon
# 3         O     28   29                  ,
# 4  CARDINAL     29   32                 12
# 5         O     32   33                  .
#   label  start  end                span
# 0   PER      0    5               Aznet
# 1     O      5    6                   ,
# 2  SPAT      6   24   r. de Loursine, 6
# 3   ACT     24   25                   .
#       label  start  end             span
# 0         O      0    5            Aznet
# 1         O      5    6                ,
# 2       LOC      6   21   r. de Loursine
# 3         O     21   22                ,
# 4  CARDINAL     22   24                6
# 5         O     24   25                .
#   label  start  end                span
# 0   PER      0    9           Beaugrand
# 1     O      9   10                   ,
# 2  SPAT     10   28   r. de Reuilly, 12
# 3   ACT     28   29                   .
#       label  start  end            span
# 0         O      0    9       Beaugrand
# 1         O      9   10               ,
# 2       LOC     10   24   r. de Reuilly
# 3         O     24   25               ,
# 4  CARDINAL     25   28              12
# 5         O     28   29               .
#   label  start  end                 span
# 0   PER      0   10           Bouillerot
# 1  DESC     10   12                    S
# 2   ACT     12   13                    .
# 3  DESC     13   14                    -
# 4   ACT     14   18                 Ange
# 5     O     18   19                    ,
# 6  SPAT     19   38   r. de Loursine, 10
# 7   ACT     38   39                    .
#       label  start  end                span
# 0         O      0   18  Bouillerot S.-Ange
# 1         O     18   19                   ,
# 2       LOC     19   34      r. de Loursine
# 3         O     34   35                   ,
# 4  CARDINAL     35   38                  10
# 5         O     38   39                   .
#   label  start  end                span
# 0   PER      0    6              Boutté
# 1     O      6    7                   ,
# 2  SPAT      7   25   r. Mouffetard, 88
# 3   ACT     25   26                   .
#       label  start  end            span
# 0         O      0    6          Boutté
# 1         O      6    7               ,
# 2       LOC      7   21   r. Mouffetard
# 3         O     21   22               ,
# 4  CARDINAL     22   25              88
# 5         O     25   26               .
#   label  start  end              span
# 0   PER      0   10        Carpentier
# 1     O     10   11                 ,
# 2  SPAT     11   27   r. du Harlay, 7
# 3     O     27   30               . (
# 4  SPAT     30   36            Marais
# 5     O     36   37                 .
# 6  SPAT     37   38                 )
#       label  start  end           span
# 0         O      0   10     Carpentier
# 1         O     10   11              ,
# 2       LOC     11   24   r. du Harlay
# 3         O     24   25              ,
# 4  CARDINAL     25   27              7
# 5         O     27   30            . (
# 6       LOC     30   36         Marais
# 7         O     36   37              .
# 8       LOC     37   38              )
#   label  start  end                 span
# 0   PER      0    9            Chevalier
# 1     O      9   10                    ,
# 2  SPAT     10   29   r. Mouffetard, 104
# 3   ACT     29   30                    .
#       label  start  end            span
# 0         O      0    9       Chevalier
# 1         O      9   10               ,
# 2       LOC     10   24   r. Mouffetard
# 3         O     24   25               ,
# 4  CARDINAL     25   29             104
# 5         O     29   30               .
#   label  start  end                   span
# 0   PER      0    7                Debruge
# 1     O      7    8                      ,
# 2  SPAT      8   29   rue S.-Dominique, 71
# 3     O     29   32                    . (
# 4  SPAT     32   45          Gros-Caillou
# 5     O     45   47                     .)
#       label  start  end               span
# 0         O      0    7            Debruge
# 1         O      7    8                  ,
# 2       LOC      8   25   rue S.-Dominique
# 3         O     25   26                  ,
# 4  CARDINAL     26   29                 71
# 5         O     29   32                . (
# 6       LOC     32   45      Gros-Caillou
# 7         O     45   47                 .)
#   label  start  end                           span
# 0   PER      0   11                    Devillepoix
# 1     O     11   12                              ,
# 2  SPAT     12   41   r. du Faub.-S.-Antoine, 212.
#       label  start  end                     span
# 0         O      0   11              Devillepoix
# 1         O     11   12                        ,
# 2       LOC     12   35   r. du Faub.-S.-Antoine
# 3         O     35   36                        ,
# 4  CARDINAL     36   41                     212.
#   label  start  end                                            span
# 0   PER      0    7                                         Dulamée
# 1   ACT      7   53  , fabric. de bière anglaise etd'esprit-de-vin
# 2     O     53   54                                               ,
# 3  SPAT     54   74                             r. Rochechouart, 44
# 4   ACT     74   75                                               .
#       label  start  end                                               span
# 0         O      0   53  Dulamée, fabric. de bière anglaise etd'esprit...
# 1         O     53   54                                                  ,
# 2       LOC     54   70                                    r. Rochechouart
# 3         O     70   71                                                  ,
# 4  CARDINAL     71   74                                                 44
# 5         O     74   75                                                  .
#   label  start  end                 span
# 0   PER      0    8             François
# 1     O      8    9                    ,
# 2  SPAT      9   28   r. Mouffetard, 116
# 3   ACT     28   29                    .
#       label  start  end            span
# 0         O      0    8        François
# 1         O      8    9               ,
# 2       LOC      9   23   r. Mouffetard
# 3         O     23   24               ,
# 4  CARDINAL     24   28             116
# 5         O     28   29               .
#   label  start  end                           span
# 0   PER      0    4                           Gibé
# 1     O      4    5                              ,
# 2  SPAT      5   34   r. du Faub.-S.-Antoine, 295.
#       label  start  end                     span
# 0         O      0    4                     Gibé
# 1         O      4    5                        ,
# 2       LOC      5   28   r. du Faub.-S.-Antoine
# 3         O     28   29                        ,
# 4  CARDINAL     29   33                      295
# 5       LOC     33   34                        .
#   label  start  end                    span
# 0   PER      0    5                   Giell
# 1     O      5    6                       ,
# 2  SPAT      6   28   r. de la Corderie, 13
# 3     O     28   31                     . (
# 4  SPAT     31   37                  Marais
# 5     O     37   38                       .
# 6  SPAT     38   39                       )
#       label  start  end                span
# 0         O      0    5               Giell
# 1         O      5    6                   ,
# 2       LOC      6   24   r. de la Corderie
# 3         O     24   25                   ,
# 4  CARDINAL     25   28                  13
# 5         O     28   31                 . (
# 6       LOC     31   37              Marais
# 7         O     37   38                   .
# 8       LOC     38   39                   )
#   label  start  end                span
# 0   PER      0   17   Christofle, (Ve.)
# 1   ACT     17   23               fabr.
# 2     O     23   24                   ,
# 3  SPAT     24   42   r. S.-Denis, 173.
#       label  start  end                     span
# 0         O      0   23  Christofle, (Ve.) fabr.
# 1         O     23   24                        ,
# 2       LOC     24   36              r. S.-Denis
# 3         O     36   37                        ,
# 4  CARDINAL     37   42                     173.
#   label  start  end                                          span
# 0     O      0    1                                             —
# 1   PER      1   21                          Christofle, (André)
# 2   ACT     21   65   fabr. de boutons pla-qués d'or et d'argent
# 3     O     65   66                                             ,
# 4  SPAT     66   92                     rue des Enfans-Rouges, 7
# 5   ACT     92   93                                             .
#       label  start  end                                               span
# 0         O      0    1                                                  —
# 1         O      1   65  Christofle, (André) fabr. de boutons pla-qué...
# 2         O     65   66                                                  ,
# 3       LOC     66   89                             rue des Enfans-Rouges
# 4         O     89   90                                                  ,
# 5  CARDINAL     90   92                                                  7
# 6         O     92   93                                                  .
#   label  start  end             span
# 0   PER      0    7          Colinet
# 1   ACT      7   14          , fabr.
# 2  SPAT     14   29  , S.-Martin, 68
# 3   ACT     29   30                .
#       label  start  end            span
# 0         O      0   14  Colinet, fabr.
# 1       LOC     14   25     , S.-Martin
# 2         O     25   26               ,
# 3  CARDINAL     26   29              68
# 4         O     29   30               .
#   label  start  end                        span
# 0   PER      0    9                   Bouillery
# 1     O      9   10                           ,
# 2  SPAT     10   36   r. du Puits-l'Ermite, 14.
#       label  start  end                   span
# 0         O      0    9              Bouillery
# 1         O      9   10                      ,
# 2       LOC     10   31   r. du Puits-l'Ermite
# 3         O     31   32                      ,
# 4  CARDINAL     32   35                     14
# 5       LOC     35   36                      .
#   label  start  end                         span
# 0   PER      0   11                  Demarseille
# 1     O     11   12                            ,
# 2  SPAT     12   39   r. du Faub.-S.-Denis, 114.
#       label  start  end                   span
# 0         O      0   11            Demarseille
# 1         O     11   12                      ,
# 2       LOC     12   33   r. du Faub.-S.-Denis
# 3         O     33   34                      ,
# 4  CARDINAL     34   38                    114
# 5       LOC     38   39                      .
#   label  start  end                 span
# 0   PER      0    5                Denis
# 1     O      5    6                    ,
# 2  SPAT      6   25   r. de Loursine, 46
# 3   ACT     25   26                    .
#       label  start  end             span
# 0         O      0    5            Denis
# 1         O      5    6                ,
# 2       LOC      6   21   r. de Loursine
# 3         O     21   22                ,
# 4  CARDINAL     22   25               46
# 5         O     25   26                .
#   label  start  end                      span
# 0   PER      0    8                  Vaillant
# 1   ACT      8   15                   , fabr.
# 2     O     15   16                         ,
# 3  SPAT     16   40   r. Aubry-le-Boucher, 43
# 4   ACT     40   41                         .
#       label  start  end                  span
# 0         O      0   15       Vaillant, fabr.
# 1         O     15   16                     ,
# 2       LOC     16   36   r. Aubry-le-Boucher
# 3         O     36   37                     ,
# 4  CARDINAL     37   40                    43
# 5         O     40   41                     .
#   label  start  end                   span
# 0   PER      0    6                 Vallée
# 1     O      6    7                      ,
# 2  SPAT      7   28   rue Saint-Denis, 374
# 3   ACT     28   29                      .
#       label  start  end              span
# 0         O      0    6            Vallée
# 1         O      6    7                 ,
# 2       LOC      7   23   rue Saint-Denis
# 3         O     23   24                 ,
# 4  CARDINAL     24   28               374
# 5         O     28   29                 .
#   label  start  end                                               span
# 0   PER      0   14                                     Barbe-Derveaux
# 1   ACT     14   76  , fabricant de brosses etpinceaux à lusage de...
# 2     O     76   77                                                  ,
# 3  SPAT     77   95                                 rue Beaubourg, 44
# 4   ACT     95   96                                                  .
#       label  start  end                                               span
# 0         O      0   76  Barbe-Derveaux, fabricant de brosses etpincea...
# 1         O     76   77                                                  ,
# 2       LOC     77   91                                     rue Beaubourg
# 3         O     91   92                                                  ,
# 4  CARDINAL     92   95                                                 44
# 5         O     95   96                                                  .
#   label  start  end                              span
# 0   PER      0    4                              Huet
# 1     O      4    5                                 ,
# 2  SPAT      5   37   rue de la Vieille-Bouclerie, 23
# 3   ACT     37   38                                 .
#       label  start  end                          span
# 0         O      0    4                          Huet
# 1         O      4    5                             ,
# 2       LOC      5   33   rue de la Vieille-Bouclerie
# 3         O     33   34                             ,
# 4  CARDINAL     34   37                            23
# 5         O     37   38                             .
#   label  start  end                      span
# 0   PER      0    4                      Jiou
# 1     O      4    5                         ,
# 2  SPAT      5   29   rue de la Barillerie, 8
# 3   ACT     29   30                         .
#       label  start  end                   span
# 0         O      0    4                   Jiou
# 1         O      4    5                      ,
# 2       LOC      5   26   rue de la Barillerie
# 3         O     26   27                      ,
# 4  CARDINAL     27   29                      8
# 5         O     29   30                      .
#   label  start  end                    span
# 0   PER      0    7                 Lamarée
# 1     O      7    8                       ,
# 2  SPAT      8   30   rue Saint-Deuis, 292.
#       label  start  end              span
# 0         O      0    7           Lamarée
# 1         O      7    8                 ,
# 2       LOC      8   24   rue Saint-Deuis
# 3         O     24   25                 ,
# 4  CARDINAL     25   30              292.
#   label  start  end               span
# 0   PER      0   17  Lecoiffier-Wallez
# 1   ACT     17   27         ,etcordier
# 2     O     27   28                  ,
# 3  SPAT     28   42      r. du Bac, 37
# 4   ACT     42   43                  .
#       label  start  end                         span
# 0         O      0   27  Lecoiffier-Wallez,etcordier
# 1         O     27   28                            ,
# 2       LOC     28   38                    r. du Bac
# 3         O     38   39                            ,
# 4  CARDINAL     39   42                           37
# 5         O     42   43                            .
#   label  start  end                    span
# 0   PER      0    6                  Lejean
# 1     O      6    7                       ,
# 2  SPAT      7   29   rue de Thionville, 36
# 3   ACT     29   30                       .
#       label  start  end                span
# 0         O      0    6              Lejean
# 1         O      6    7                   ,
# 2       LOC      7   25   rue de Thionville
# 3         O     25   26                   ,
# 4  CARDINAL     26   29                  36
# 5         O     29   30                   .
#   label  start  end                                               span
# 0   PER      0    7                                            Saunier
# 1   ACT      7   67  , fabr. de brosses de Lyon et pin-ceaux pour ...
# ...
# 1         O      4   10       AIJUHH
# 2         O     10   12           ed
# 3       LOC     12   23  ve(RN DEHTe
# 4  CARDINAL     23   27         LEF
#   label  start  end                span
# 0     O      0    3                 —17
# 1   PER      3   20   Delasalle, jeune
# 2     O     20   21                   ,
# 3  SPAT     21   32         Lhumpg, FF
# 4     O     32   33                   .
# 5  SPAT     33   51  K.E. des: Petis
#       label  start  end                span
# 0         O      0    3                 —17
# 1         O      3   20   Delasalle, jeune
# 2         O     20   21                   ,
# 3       LOC     21   28             Lhumpg
# 4         O     28   29                   ,
# 5  CARDINAL     29   32                  FF
# 6         O     32   33                   .
# 7       LOC     33   51  K.E. des: Petis
#   label  start  end                       span
# 0   PER      0   19        David ( J. B. L. ),
# 1  SPAT     19   44   R. r. des PetitsChamps4
#       label  start  end                      span
# 0         O      0   19       David ( J. B. L. ),
# 1       LOC     19   43   R. r. des PetitsChamps
# 2  CARDINAL     43   44                         4
#   label  start  end                   span
# 0   PER      0    9              Chenavard
# 1   ACT      9   30   ( manuf d'élof nouo.
# 2     O     30   32                     1
# 3  SPAT     32   53  lii de ThorIgI1E)7
#       label  start  end                            span
# 0         O      0   30  Chenavard ( manuf d'élof nouo.
# 1         O     30   32                              1
# 2       LOC     32   48                lii de ThorIgI1
# 3         O     48   50                              E
# 4  CARDINAL     50   53                             )7
#   label  start  end                   span
# 0     O      0    1                      —
# 1   PER      1   22  Cheldeville et comp.
# 2  SPAT     22   39       R. S. Denis, 188
# 3   PER     39   40                      .
#       label  start  end                   span
# 0         O      0    1                      —
# 1         O      1   22  Cheldeville et comp.
# 2       LOC     22   34            R. S. Denis
# 3         O     34   35                      ,
# 4  CARDINAL     35   39                    188
# 5         O     39   40                      .
#   label  start  end                 span
# 0   PER      0    7              Chauvin
# 1     O      7    8                    ,
# 2  SPAT      8   27   R. Thibauthode.If.
#       label  start  end             span
# 0         O      0    7          Chauvin
# 1         O      7    8                ,
# 2       LOC      8   23   R. Thibauthode
# 3         O     23   24                .
# 4  CARDINAL     24   25                I
# 5       LOC     25   27               f.
#   label  start  end                           span
# 0   PER      0    8                       Harlet l
# 1     O      8   10                             ls
# 2   ACT     10   27               (nouuleh modes.)
# 3  SPAT     27   56  R. desGosses Monitmatare;:A
#       label  start  end                       span
# 0         O      0    8                   Harlet l
# 1         O      8   10                         ls
# 2         O     10   27           (nouuleh modes.)
# 3       LOC     27   52  R. desGosses Monitmatare
# 4         O     52   54                         ;:
# 5  CARDINAL     54   56                         A
#   label  start  end               span
# 0   PER      0    8           Charbant
# 1     O      8    9                  ,
# 2  SPAT      9   26   R.S.:Honeré4 129
# 3     O     26   27                  .
#       label  start  end          span
# 0         O      0    8      Charbant
# 1         O      8    9             ,
# 2       LOC      9   21   R.S.:Honeré
# 3         O     21   22             4
# 4  CARDINAL     22   26           129
# 5         O     26   27             .
#   label  start  end          span
# 0   PER      0   12  Chambert (ra
# 1   ACT     12   23   a) (en sros
# 2  SPAT     24   34    venot, 24
# 3     O     34   35             .
# 4  SPAT     35   43      R. Thé-
#       label  start  end                     span
# 0         O      0   23  Chambert (raa) (en sros
# 1       LOC     24   30                   venot
# 2         O     30   31                        ,
# 3  CARDINAL     31   34                       24
# 4         O     34   35                        .
# 5       LOC     35   43                 R. Thé-
#   label  start  end                   span
# 0     O      0    1                      T
# 1   PER      2   16         Chabanel ( L.
# 2     O     16   18                     );
# 3  SPAT     18   39   R. Bertin- Poiree,T
#       label  start  end                span
# 0         O      0    1                   T
# 1         O      2   16      Chabanel ( L.
# 2         O     16   18                  );
# 3       LOC     18   36   R. Bertin- Poiree
# 4         O     36   37                   ,
# 5  CARDINAL     37   39                  T
# NUM 1666
# TChabanel ( L.); R. Bertin- Poiree,T
#   label  start  end                               span
# 0   PER      0   12                       Cartier fils
# 1   ACT     12   45   (etoffes pour membtes efHijde
# 2  SPAT     45   56                         ln Lbi, 89
# 3     O     56   59                                .E
#       label  start  end                                           span
# 0         O      0   45  Cartier fils (etoffes pour membtes efHijde
# 1       LOC     45   52                                         ln Lbi
# 2         O     52   53                                              ,
# 3  CARDINAL     53   56                                             89
# 4         O     56   59                                            .E
# NUM 1667
# Cartier fils (etoffes pour membtes efHijde ln Lbi, 89.E
#   label  start  end                           span
# 0   PER      0   18             apentier el Flenry
# 1   ACT     18   27                       (étoffes
# 2   PER     27   29                             ),
# 3  SPAT     29   58   R. S.i-1EDeuis 3231.3111.
# 4     O     58   64                         .' r2.
#       label  start  end                           span
# 0         O      0   29  apentier el Flenry (étoffes),
# 1       LOC     29   47              R. S.i-1EDeuis
# 2  CARDINAL     47   52                           3231
# 3         O     52   53                              .
# 4  CARDINAL     53   57                           3111
# 5       LOC     57   58                              .
# 6         O     58   64                         .' r2.
# NUM 1668
# apentier el Flenry (étoffes), R. S.i-1EDeuis 3231.3111..' r2.
#   label  start  end                                 span
# 0     O      0    1                                    —
# 1   PER      1   24              Boyer el. Alary frères
# 2   ACT     24   34                            (en botte
# 3   PER     34   36                                   ),
# 4  SPAT     36   71   R.*2N.StMeryr 4L. . M .2.——T
#       label  start  end                                 span
# 0         O      0    1                                    —
# 1         O      1   36  Boyer el. Alary frères (en botte),
# 2       LOC     36   52                      R.*2N.StMeryr
# 3         O     52   54                                    4
# 4       LOC     54   61                              L. . M
# 5         O     61   62                                    .
# 6  CARDINAL     62   64                                   2
# 7         O     64   69                                .——
# 8       LOC     69   71                                   T
# NUM 1669
# —Boyer el. Alary frères (en botte), R.*2N.StMeryr 4L. . M .2.——T
#   label  start  end                    span
# 0   PER      0    6                  Bondon
# 1   ACT      6   22         (de bas de soie
# 2     O     22   24                       1
# 3   ACT     24   25                       ,
# 4  SPAT     25   26                       B
# 5     O     26   27                       ?
# 6  SPAT     27   49   deglaTMůnn.IIL:i1ul
# 7     O     50   52                       P
# 8  SPAT     52   53                       W
# 9     O     53   55                      1h
#       label  start  end                    span
# 0         O      0   22  Bondon (de bas de soie
# 1         O     22   24                       1
# 2         O     24   25                       ,
# 3       LOC     25   26                       B
# 4         O     26   27                       ?
# 5       LOC     27   49   deglaTMůnn.IIL:i1ul
# 6         O     50   52                       P
# 7  CARDINAL     52   53                       W
# 8         O     53   55                      1h
# NUM 1670
# Bondon (de bas de soie 1,B? deglaTMůnn.IIL:i1ul PW1h
#   label  start  end            span
# 0   PER      0    7         DoREaud
# 1   ACT      7   19     FECOMP.R.S
# 2  SPAT     19   33  , Honorel, 334
#       label  start  end                 span
# 0         O      0   19  DoREaud FECOMP.R.S
# 1       LOC     19   28            , Honorel
# 2         O     28   29                    ,
# 3  CARDINAL     29   33                  334
#   label  start  end             span
# 0   PER      0    5            Bouna
# 1   ACT      5   17      (en baited)
# 2  SPAT     17   32   Ma SiDenis, An
#       label  start  end               span
# 0         O      0   17  Bouna (en baited)
# 1       LOC     17   28         Ma SiDenis
# 2         O     28   29                  ,
# 3  CARDINAL     29   32                 An
# NUM 1672
# Bouna (en baited) Ma SiDenis, An
#   label  start  end            span
# 0   PER      0    8        LDÉnudet
# 1     O      8   10              "
# 2  SPAT     10   24  R. Phcvenot, 5
# 3     O     24   25               .
#       label  start  end         span
# 0         O      0    8     LDÉnudet
# 1         O      8   10           "
# 2       LOC     10   21  R. Phcvenot
# 3         O     21   22            ,
# 4  CARDINAL     22   24            5
# 5         O     24   25            .
#   label  start  end                 span
# 0   PER      0    5                Bizet
# 1   ACT      5   17          ( d'etoffas
# 2     O     17   20                   y.
# 3  SPAT     20   39   R. du Pet Fonl, 26
# 4   ACT     39   40                    .
#       label  start  end               span
# 0         O      0   17  Bizet ( d'etoffas
# 1         O     17   20                 y.
# 2       LOC     20   35     R. du Pet Fonl
# 3         O     35   36                  ,
# 4  CARDINAL     36   39                 26
# 5         O     39   40                  .
# NUM 1674
# Bizet ( d'etoffas y. R. du Pet Fonl, 26.
#   label  start  end               span
# 0   PER      0    9          Bessanan
# 1     O      9   15              botte
# 2  SPAT     15   32  R. S. Deniša 229
# 3     O     32   33                  .
#       label  start  end           span
# 0         O      0    9      Bessanan
# 1         O      9   15          botte
# 2       LOC     15   28  R. S. Deniša
# 3  CARDINAL     28   32            229
# 4         O     32   33              .
# NUM 1675
# Bessanan botteR. S. Deniša 229.
#   label  start  end                     span
# 0     O      0    1                        5
# 1   PER      1    9                 Beruard
# 2     O      9   11                       ',
# 3  SPAT     11   34   Hlllle-l'Arbre sec : 5
# 4     O     34   35                        .
#       label  start  end                 span
# 0         O      0    1                    5
# 1         O      1    9             Beruard
# 2         O      9   11                   ',
# 3       LOC     11   30   Hlllle-l'Arbre sec
# 4         O     30   32                    :
# 5  CARDINAL     32   34                    5
# 6         O     34   35                    .
# NUM 1676
# 5Beruard', Hlllle-l'Arbre sec : 5.
#   label  start  end               span
# 0   PER      0    4               HeTÉ
# 1     O      4    8               eřT
# 2  SPAT      8   25   Alen.1i HBoncher
# 3     O     25   26                  4
#   label  start  end               span
# 0     O      0    4               HeTÉ
# 1     O      4    8               eřT
# 2   LOC      8   25   Alen.1i HBoncher
# 3     O     25   26                  4
# NUM 1677
# HeTÉeřT Alen.1i HBoncher4
#   label  start  end           span
# 0     O      0    9      WETV1
# 1   ACT      9   12            DE
# 2     O     12   16           en ,
# 3  SPAT     16   29   L DHtave114
#       label  start  end       span
# 0         O      0    9  WETV1
# 1         O      9   12        DE
# 2         O     12   16       en ,
# 3       LOC     16   25   L DHtave
# 4  CARDINAL     25   29       114
# NUM 1678
# WETV1DEen , L DHtave114
#   label  start  end       span
# 0   PER      0    5      Davle
# 1     O      5    7         ci
# 2  SPAT      7   15    HlsiirH
# 3     O     15   16          ,
# 4  SPAT     16   18         IL
# 5     O     18   19          .
# 6  SPAT     19   28   aeTroura
# 7     O     28   35     restai
#       label  start  end       span
# 0         O      0    5      Davle
# 1         O      5    7         ci
# 2       LOC      7   15    HlsiirH
# 3         O     15   16          ,
# 4  CARDINAL     16   18         IL
# 5         O     18   19          .
# 6       LOC     19   28   aeTroura
# 7         O     28   35     restai
# NUM 1679
# Davleci HlsiirH,IL. aeTroura restai
#   label  start  end          span
# 0   PER      0    6        DRTIEL
# 1     O      6    7             Y
# 2   ACT      7    9            É
# 3     O      9   10             H
# 4   ACT     10   13            DO
# 5     O     13   18         EIENE
# 6  SPAT     18   30  AH.S. DeN1
# 7     O     30   31             E
#       label  start  end       span
# 0         O      0    6     DRTIEL
# 1         O      6    7          Y
# 2         O      7    9         É
# 3         O      9   10          H
# 4         O     10   13         DO
# 5         O     13   18      EIENE
# 6       LOC     18   27  AH.S. DeN
# 7  CARDINAL     28   30         1
# 8         O     30   31          E
# NUM 1680
# DRTIELYÉH DOEIENEAH.S. DeN1E
#   label  start  end                  span
# 0   PER      0    7               Barbier
# 1     O      7    9                     (
# 2   ACT     10   13                   �ét
# 3  SPAT     13   17                  oſſe
# 4   ACT     17   18                     s
# 5  SPAT     18   28            1HonnOiS'
# 6     O     28   29                     ,
# 7  SPAT     29   31                     2
# 8     O     31   32                     .
# 9  SPAT     32   52  R. des: Beur-LT1M
#        label  start  end              span
# 0          O      0    7           Barbier
# 1          O      7    9                 (
# 2          O     10   13               �ét
# 3        LOC     13   17              oſſe
# 4          O     17   18                 s
# 5        LOC     18   27         1HonnOiS
# 6          O     27   28                 '
# 7          O     28   29                 ,
# 8   CARDINAL     29   31                 2
# 9          O     31   32                 .
# 10       LOC     32   48  R. des: Beur-L
# 11  CARDINAL     48   52              T1M
# NUM 1681
# Barbier ( �étoſſes1HonnOiS', 2.R. des: Beur-LT1M
#   label  start  end                           span
# 0   PER      0   20           Anbinean et Pluchart
# 1   ACT     20   38              ['etuon venites.]
# 2     O     38   42                           ,—1
# 3  SPAT     42   71  Lpassagë des Fetits Peres,—
#       label  start  end                                    span
# 0         O      0   38  Anbinean et Pluchart ['etuon venites.]
# 1         O     38   42                                    ,—1
# 2       LOC     42   68              Lpassagë des Fetits Peres
# 3         O     68   69                                       ,
# 4  CARDINAL     69   71                                      —
# NUM 1682
# Anbinean et Pluchart ['etuon venites.],—1Lpassagë des Fetits Peres,—
#   label  start  end       span
# 0   PER      0    9  ETH.SEnt
# 1     O      9   13       IFF
# 2  SPAT     13   17       Pif
#   label  start  end       span
# 0     O      0    9  ETH.SEnt
# 1     O      9   13       IFF
# 2   LOC     13   17       Pif
# NUM 1683
# ETH.SEntIFFPif
#   label  start  end            span
# 0   PER      0    6          HAMAGI
# 1   ACT      6   15        et domp.
# 2  SPAT     15   29   F,3..Deni 150
#       label  start  end             span
# 0         O      0   15  HAMAGI et domp.
# 1       LOC     15   25        F,3..Deni
# 2  CARDINAL     25   29              150
# NUM 1684
# HAMAGI et domp. F,3..Deni 150

# %%
columns = ["index","entry","entry_xml","spans_gold","tags_gold","spans_preds","tags_preds"]
df = pd.DataFrame(stats,columns=columns)
df
# Out:
#       index                                              entry  \
# 0         0  Arnoult, fabr. de moules de boutons, r. de
# la ...
# 1         1                           Bayard, r. du Roule, 21.
# 2         2                         Berchet, r. du Temple, 71.
# 3         3  Bouchet, fabr., r. du Cimetière-Saint-
# Nicolas...
# 4         4  Chardin et comp., fabr. de boutons de
# métal ar...
# ...     ...                                                ...
# 1663   1663  Harlet lls (nouuleh modes.)R. des
# Gosses Monit...
# 1664   1664                        Charbant, R.S.:Honeré4 129.
# 1665   1665        Chambert (raa) (en sros
#
# venot, 24.
# R. Thé-
# 1666   1671                  DoREaud FECOMP.
# R.S, Honorel, 334
# 1667   1673                          LDÉnudet
# "R. Phcvenot, 5.
#
#                                               entry_xml  \
# 0     <PER>Arnoult</PER><ACT>, fabr. de moules de bo...
# 1     <PER>Bayard</PER>,<SPAT><LOC> r. du Roule</LOC...
# 2     <PER>Berchet</PER>,<SPAT><LOC> r. du Temple</L...
# 3     <PER>Bouchet</PER><ACT>, fabr.</ACT>,<SPAT><LO...
# 4     <PER>Chardin et comp.</PER><DESC><ACT>, fabr. ...
# ...                                                 ...
# 1663  <PER>Harlet l</PER>ls<ACT> (nouuleh modes.)</A...
# 1664  <PER>Charbant</PER>,<SPAT><LOC> R.S.:Honeré</L...
# 1665  <PER>Chambert (ra</PER><ACT>a) (en sros</ACT><...
# 1666  <PER>DoREaud</PER><ACT> FECOMP.
# R.S</ACT><SPAT...
# 1667  <PER>LDÉnudet</PER>
# "<SPAT><LOC>R. Phcvenot</L...
#
#                                              spans_gold  \
# 0     [▁Arn, oul, t, ,, ▁fa, br, ., ▁de, ▁moules, ▁d...
# 1       [▁Bay, ard, ,, ▁r, ., ▁du, ▁Rou, le, ,, ▁21, .]
# 2       [▁Ber, chet, ,, ▁r, ., ▁du, ▁Temple, ,, ▁71, .]
# 3     [▁Bouche, t, ,, ▁fa, br, ., ,, ▁r, ., ▁du, ▁C,...
# 4     [▁Char, din, ▁et, ▁comp, ., ,, ▁fa, br, ., ▁de...
# ...                                                 ...
# 1663  [▁Har, let, ▁l, l, s, ▁(, nou, ule, h, ▁modes,...
# 1664  [▁Char, b, ant, ,, ▁R, ., S, ., :, H, one, ré,...
# 1665  [▁Chamb, ert, ▁(, ra, a, ), ▁(, en, ▁s, ros, ▁...
# 1666  [▁L, D, É, nu, de, t, ▁", R, ., ▁Ph, c, ven, o...
# 1667  [▁Be, s, san, ▁an, ▁botte, ▁R, ., ▁S, ., ▁De, ...
#
#                                               tags_gold  \
# 0     [I-PER+O, I-PER+O, I-PER+O, O+O, I-ACT+O, I-AC...
# 1     [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...
# 2     [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...
# 3     [I-PER+O, I-PER+O, O+O, I-ACT+O, I-ACT+O, I-AC...
# 4     [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
# ...                                                 ...
# 1663  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
# 1664  [I-PER+O, I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC,...
# 1665  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
# 1666  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
# 1667  [I-PER+O, I-PER+O, I-PER+O, I-ACT+O, I-ACT+O, ...
#
#                                             spans_preds  \
# 0     [▁Arn, oul, t, ,, ▁fa, br, ., ▁de, ▁moules, ▁d...
# 1       [▁Bay, ard, ,, ▁r, ., ▁du, ▁Rou, le, ,, ▁21, .]
# 2       [▁Ber, chet, ,, ▁r, ., ▁du, ▁Temple, ,, ▁71, .]
# 3     [▁Bouche, t, ,, ▁fa, br, ., ,, ▁r, ., ▁du, ▁C,...
# 4     [▁Char, din, ▁et, ▁comp, ., ,, ▁fa, br, ., ▁de...
# ...                                                 ...
# 1663  [▁Har, let, ▁l, l, s, ▁(, nou, ule, h, ▁modes,...
# 1664  [▁Char, b, ant, ,, ▁R, ., S, ., :, H, one, ré,...
# 1665  [▁Chamb, ert, ▁(, ra, a, ), ▁(, en, ▁s, ros, ▁...
# 1666  [▁Do, RE, aud, ▁FE, COM, P, ., ▁R, ., S, ,, ▁H...
# 1667  [▁L, D, É, nu, de, t, ▁", R, ., ▁Ph, c, ven, o...
#
#                                              tags_preds
# 0     [I-PER+O, I-PER+O, I-PER+O, I-ACT+O, I-ACT+O, ...
# 1     [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...
# 2     [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...
# 3     [I-PER+O, I-PER+O, I-ACT+O, I-ACT+O, I-ACT+O, ...
# 4     [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
# ...                                                 ...
# 1663  [I-PER+O, I-PER+O, I-PER+O, O+O, O+O, I-ACT+O,...
# 1664  [I-PER+O, I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC,...
# 1665  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-ACT+O, ...
# 1666  [I-PER+O, I-PER+O, I-PER+O, I-ACT+O, I-ACT+O, ...
# 1667  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
#
# [1668 rows x 7 columns]

# %% [markdown]
# ## F1-Score ranking
# F1-Score is calculated for each entry using seqeval library :
# * entities are rebuild using joint-labels with seqeval lib
# * f1-score is calculted for each entry

# %%
from seqeval.metrics import f1_score

scores = []
count = 0
for i in range(len(df)):
    y_preds = df.iloc[i]["tags_preds"]
    y_true = df.iloc[i]["tags_gold"]
    try:
        f1 = f1_score([y_true],[y_preds])
        scores.append(f1)
    except:
        count += 1
        print(df.iloc[i])
print(count)
# Out:
# /lrde/home2/stual/.venv/python_3_9/lib/python3.10/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: O+O seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# 0

# %%
df["f1"] = scores
df = df.sort_values(by=['f1']).reset_index()
del df["level_0"]

# %%
df
# Out:
#       index                                         entry  \
# 0      1673                     LDÉnudet
# "R. Phcvenot, 5.
# 1      1620  Quevin (charron), R. des Petites-
# Eurefi IRs
# 2      1647                     VuRTNRupH, M deS:HIDNUS
# D
# 3      1649  R H.
# Horang cadel
# 25.
# Ghenet
#
#
# du GFos-
# E
# "
# 4      1651                  TOS
#
# ☞OOLGJ†DOE
# 1*
# Penis g.o
# ...     ...                                           ...
# 1663   1309  Mancel, Pépinière, 92, et avenue
# Percier, 4.
# 1664   1128             Martine J.-L.)
# "Bourguignons, 29.
# 1665   1088                         Ferrand, Glacière, 27
# 1666   1543                   Auger, R. de In Verrerie,
# ☞
# 1667    936                Vigier
# (baronne de
# "Rivoli, 30
#
#                                               entry_xml  \
# 0     <PER>LDÉnudet</PER>
# "<SPAT><LOC>R. Phcvenot</L...
# 1     <PER>Quevin (</PER><ACT>charron</ACT><PER>),</...
# 2     <PER>VuRT</PER>NR<PER>up</PER>H,<SPAT><LOC> M ...
# 3     R<SPAT><LOC> H.
# Horang ca</LOC>del<CARDINAL>
# ...
# 4     TOS
#
# ☞OOLGJ†DOE
# 1*<SPAT><LOC>
# Penis g</LOC></S...
# ...                                                 ...
# 1663  <PER>Mancel</PER>,<SPAT><LOC> Pépinière</LOC>,...
# 1664  <PER>Martine J.-L.)</PER>
# "<SPAT><LOC>Bourguig...
# 1665  <PER>Ferrand</PER>,<SPAT><LOC> Glacière</LOC>,...
# 1666  <PER>Auger</PER>,<SPAT><LOC> R. de In Verrerie...
# 1667  <PER>Vigier
# (baronne de</PER>
# "<SPAT><LOC>Rivo...
#
#                                              spans_gold  \
# 0     [▁Be, s, san, ▁an, ▁botte, ▁R, ., ▁S, ., ▁De, ...
# 1     [▁Que, vin, ▁(, char, ron, ),, ▁R, ., ▁des, ▁P...
# 2     [▁Vu, RT, N, R, up, H, ,, ▁M, ▁de, S, :, H, ID...
# 3     [▁R, ▁H, ., ▁Hor, ang, ▁ca, del, ▁25, ., ▁Gh, ...
# 4     [▁T, OS, ▁, <unk>, OO, LG, J, <unk>, DO, E, ▁1...
# ...                                                 ...
# 1663  [▁Man, cel, ,, ▁P, épi, nière, ,, ▁92, ,, ▁et,...
# 1664  [▁Martine, ▁J, ., -, L, ., ), ▁", Bou, r, gu, ...
# 1665               [▁, Ferrand, ,, ▁Gla, cière, ,, ▁27]
# 1666  [▁Au, ger, ,, ▁R, ., ▁de, ▁In, ▁Verre, rie, ,,...
# 1667  [▁Vig, ier, ▁(, bar, onne, ▁de, ▁", R, iv, oli...
#
#                                               tags_gold  \
# 0     [I-PER+O, I-PER+O, I-PER+O, I-ACT+O, I-ACT+O, ...
# 1     [I-PER+O, I-PER+O, I-ACT+O, I-ACT+O, I-ACT+O, ...
# 2     [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
# 3     [O+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PE...
# 4     [I-PER+O, I-PER+O, I-ACT+O, I-ACT+O, I-ACT+O, ...
# ...                                                 ...
# 1663  [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...
# 1664  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
# 1665  [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...
# 1666  [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...
# 1667  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...
#
#                                             spans_preds  \
# 0     [▁L, D, É, nu, de, t, ▁", R, ., ▁Ph, c, ven, o...
# 1     [▁Que, vin, ▁(, char, ron, ),, ▁R, ., ▁des, ▁P...
# 2     [▁Vu, RT, N, R, up, H, ,, ▁M, ▁de, S, :, H, ID...
# 3     [▁R, ▁H, ., ▁Hor, ang, ▁ca, del, ▁25, ., ▁Gh, ...
# 4     [▁T, OS, ▁, ☞, OO, LG, J, †, DO, E, ▁1, *, ▁Pe...
# ...                                                 ...
# 1663  [▁Man, cel, ,, ▁P, épi, nière, ,, ▁92, ,, ▁et,...
# 1664  [▁Martine, ▁J, ., -, L, ., ), ▁", Bou, r, gu, ...
# 1665               [▁, Ferrand, ,, ▁Gla, cière, ,, ▁27]
# 1666  [▁Au, ger, ,, ▁R, ., ▁de, ▁In, ▁Verre, rie, ,,...
# 1667  [▁Vig, ier, ▁(, bar, onne, ▁de, ▁", R, iv, oli...
#
#                                              tags_preds   f1
# 0     [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...  0.0
# 1     [I-PER+O, I-PER+O, I-PER+O, I-ACT+O, I-ACT+O, ...  0.0
# 2     [I-PER+O, I-PER+O, O+O, O+O, I-PER+O, O+O, O+O...  0.0
# 3     [O+O, I-SPAT+i_LOC, I-SPAT+i_LOC, I-SPAT+i_LOC...  0.0
# 4     [O+O, O+O, O+O, O+O, O+O, O+O, O+O, O+O, O+O, ...  0.0
# ...                                                 ...  ...
# 1663  [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...  1.0
# 1664  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...  1.0
# 1665  [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...  1.0
# 1666  [I-PER+O, I-PER+O, O+O, I-SPAT+i_LOC, I-SPAT+i...  1.0
# 1667  [I-PER+O, I-PER+O, I-PER+O, I-PER+O, I-PER+O, ...  1.0
#
# [1668 rows x 8 columns]

# %%
import pylab as pl

df.hist(column='f1',bins=40,sharey=True, sharex=True)
pl.suptitle('Entery-scale F1-Score distribution over test set')
# Out:
# Text(0.5, 0.98, 'Entery-scale F1-Score distribution over test set')

# %% [markdown]
# ### 15-Top worst

# %%
for i in range(0,150):
    print(f"INDEX {i}")
    print(df.iloc[i]["entry"])
    print(df.iloc[i]["entry_xml"])
    print(f"F1-Score : {df.iloc[i]['f1']}")
    print("")
# Out:
# INDEX 0
# LDÉnudet"R. Phcvenot, 5.
# <PER>LDÉnudet</PER>"<SPAT><LOC>R. Phcvenot</LOC>,<CARDINAL> 5</CARDINAL></SPAT>.
# F1-Score : 0.0
#
# INDEX 1
# Quevin (charron), R. des Petites-Eurefi IRs
# <PER>Quevin (</PER><ACT>charron</ACT><PER>),</PER><SPAT><LOC> R. des Petites-Eurefi IRs</LOC></SPAT>
# F1-Score : 0.0
#
# INDEX 2
# VuRTNRupH, M deS:HIDNUSD
# <PER>VuRT</PER>NR<PER>up</PER>H,<SPAT><LOC> M deS:HIDN</LOC></SPAT>USD
# F1-Score : 0.0
#
# INDEX 3
# R H. Horang cadel25.Ghenetdu GFos-E"
# R<SPAT><LOC> H. Horang ca</LOC>del<CARDINAL>25</CARDINAL></SPAT>.<SPAT><LOC>Ghenetdu GFos-E</LOC></SPAT>"
# F1-Score : 0.0
#
# INDEX 4
# TOS☞OOLGJ†DOE1*Penis g.o
# TOS☞OOLGJ†DOE1*<SPAT><LOC>Penis g</LOC></SPAT>.o
# F1-Score : 0.0
#
# INDEX 5
# FiRion (H,pla ce des complVictoiresgétoff es
# <PER>FiRion (H,</PER><ACT>pla ce</ACT><SPAT><LOC> des complVictoiresgétoff</LOC></SPAT> es
# F1-Score : 0.0
#
# INDEX 6
# Aubert, (Mad.) pourtour du théâtre Franç.
# <PER>Aubert,</PER><ACT> (</ACT><PER>M</PER><ACT>ad</ACT><PER>.)</PER><SPAT><LOC> pourtour du théâtre Franç.</LOC></SPAT>
# F1-Score : 0.0
#
# INDEX 7
# Chambert (raa) (en srosvenot, 24.R. Thé-
# <PER>Chambert (ra</PER><ACT>a) (en sros</ACT><SPAT><LOC>venot</LOC>,<CARDINAL> 24</CARDINAL></SPAT>.<SPAT><LOC>R. Thé-</LOC></SPAT>
# F1-Score : 0.0
#
# INDEX 8
# Lemichez (Alp.), horticulteur,O 1845 O 1816, O 1846, O1847, 0 1847, O 1847, Trois-Couronnes, 18.
# <PER>Lemichez (Alp.),</PER><DESC><ACT> horticulteur</ACT><TITREP>,O 1845 O 1816, O 1846, O1847, 0 1847, O 1847</TITREP></DESC><SPAT><LOC>, Trois-Couronnes</LOC>,<CARDINAL> 18</CARDINAL></SPAT><DESC><TITREP>.</TITREP></DESC>
# F1-Score : 0.09090909090909091
#
# INDEX 9
# Verdier (Vor) père, spécialité derosiers, pivoines, noureautes d'ar-bustes et plantes de plein air, Odécernée par la société centraled'horticuiture 1845;  S. C.,d'horticulture, 1841 et 1844 ;A Société des horticulteurs réu-nis;  Société nationale d'hor-ticulture 1842; D 1849, rue desTrois-Ormes, 5, à la gare d'I-vry.
# <PER>Verdier (Vor) père</PER><DESC><ACT>, spécialité derosiers, pivoines, noureautes d'ar-bustes et plantes de plein air</ACT>, Odécernée par la société centraled'horticuiture 1845;  S. C.,d'horticulture,<TITREP> 18</TITREP>41 et<TITREP> 18</TITREP>44 ;A Société des horticulteurs réu-nis;  Société nationale d'hor-ticulture<TITREP> 1842</TITREP>;<TITREP> D 18</TITREP>49</DESC>,<SPAT><LOC> rue desTrois-Ormes</LOC>,<CARDINAL> 5</CARDINAL>, à<LOC> la gare d'I-vry</LOC></SPAT><DESC>.</DESC>
# F1-Score : 0.18750000000000003
#
# INDEX 10
# Dumont ,R des Fosseg S. Germain-—IjkAuxerroi, I
# <PER>Dumont</PER> ,<SPAT><LOC>R des Fosseg S. Germain</LOC>-—<LOC>IjkAuxerroi</LOC>,<CARDINAL> I</CARDINAL></SPAT>
# F1-Score : 0.2
#
# INDEX 11
# Gavini (Denis), représentant du peuple (Cor-se), Tronchet, 1.
# <PER>Gavini (Denis),</PER><ACT> représentant du peuple (Cor-se</ACT><SPAT><LOC>), Tronchet</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.20000000000000004
#
# INDEX 12
# Harlet lls (nouuleh modes.)R. desGosses Monitmatare;:A
# <PER>Harlet l</PER>ls<ACT> (nouuleh modes.)</ACT><SPAT><LOC>R. desGosses Monitmatare</LOC>;:<CARDINAL>A</CARDINAL></SPAT>
# F1-Score : 0.20000000000000004
#
# INDEX 13
# Chauvière (Alexandre), Roquette,152, spécialité de dahlias, géra-niums, plantes nouvelles et lesplus rares, de serre-chaude, serretempérée et de pleine terre, ayantreçu 20 médailles d'or et d'ar-gent aux diverses expositions; ex-pédition pour la France et l'é-tranger.
# <PER>Chauvière (Alexandre),</PER><SPAT><LOC> Roquette</LOC>,<CARDINAL>152,</CARDINAL></SPAT><DESC><ACT> spécialité de dahlias, géra-niums, plantes nouvelles et lesplus rares, de serre-chaud</ACT>e<ACT>,</ACT> serretempérée et de pleine terre, ayantreçu 20 médailles d<ACT>'</ACT>or et d<ACT>'</ACT>ar-gent aux diverses expositions; ex-pédition pour la France et l'é-tranger.</DESC>
# F1-Score : 0.2105263157894737
#
# INDEX 14
# Henraux (S.), propriétaire de car-rières à l'étranger; maisons àCarrara (Modène) et à Seravezza(Toscane), Tronchet, 9.
# <PER>Henraux (S.),</PER><ACT> propriétaire de car-rières à l'étranger</ACT>;<SPAT><FT> maisons</FT> à<LOC>Carrara</LOC></SPAT><DESC> (</DESC><SPAT><LOC>Modène</LOC></SPAT><DESC>) et</DESC><SPAT> à<LOC> Seravezza(Toscane), Tronchet</LOC>,<CARDINAL> 9</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.2222222222222222
#
# INDEX 15
# Blonelu-du-Rosne, R. du P. Carr. 8.
# <PER>Blonelu</PER><DESC>-du-Rosne</DESC>,<SPAT><LOC> R. du P. Carr</LOC>.<CARDINAL> 8</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.2222222222222222
#
# INDEX 16
# Goutereau, sous-chef de bureau à la préfec-ture dela šerČ.
# <PER>Goutereau</PER><ACT>, sous-chef de bureau à la</ACT><DESC> pré</DESC><ACT>fe</ACT><SPAT><LOC>c-ture dela šer</LOC></SPAT>Č<ACT>.</ACT>
# F1-Score : 0.2222222222222222
#
# INDEX 17
# Vidal (charronY K, du Baco33.
# <PER>Vidal (</PER><ACT>charronY</ACT> K<SPAT><LOC>, du Baco</LOC><CARDINAL>33</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.22222222222222224
#
# INDEX 18
# Forney (Ls), Fosses-St-Marc., 63.
# <PER>Forney (Ls),</PER><SPAT><LOC> Fosses-St-Marc</LOC>.,<CARDINAL> 63</CARDINAL></SPAT><PER>.</PER>
# F1-Score : 0.22222222222222224
#
# INDEX 19
# DoREaud FECOMP.R.S, Honorel, 334
# <PER>DoREaud</PER><ACT> FECOMP.R.S</ACT><SPAT><LOC>, Honorel</LOC>,<CARDINAL> 334</CARDINAL></SPAT>
# F1-Score : 0.22222222222222224
#
# INDEX 20
# 17Hpnariug Etaees a aparanue du Triha de pierresprlop.rFuPar--
# 17<PER>Hpnari</PER>ug<ACT> Etaees a apara</ACT><DESC>nue du Triha de pierresprlop</DESC>.r<SPAT><LOC>FuPar--</LOC></SPAT>
# F1-Score : 0.22222222222222224
#
# INDEX 21
# Ledure, ſabr. de bronzes et pendules, rueNeuve des-Petits-Champs, au coin decelle Chabanais.
# <PER>Ledure</PER><ACT>, ſabr. de bronzes et pendules</ACT>,<SPAT><LOC> rueNeuve des-Petits-Champs, au coin decelle Chabanais</LOC></SPAT><ACT>.</ACT>
# F1-Score : 0.25
#
# INDEX 22
# TELeRI SPMartin y 15r.
# <PER>TELeRI</PER><SPAT><LOC> SPMartin</LOC> y<CARDINAL> 15</CARDINAL></SPAT>r.
# F1-Score : 0.25
#
# INDEX 23
# rFumevfctofresl, b. des BOUTUOITGIS, S.
# r<PER>Fumevfctofres</PER>l,<SPAT><LOC> b. des BOUTUOITGIS</LOC>,<CARDINAL> S</CARDINAL></SPAT>.
# F1-Score : 0.25
#
# INDEX 24
# —17Delasalle, jeune,Lhumpg, FF.K.E. des: Petis
# —17<PER>Delasalle, jeune</PER>,<SPAT><LOC>Lhumpg</LOC>,<CARDINAL> FF</CARDINAL></SPAT>.<SPAT><LOC>K.E. des: Petis</LOC></SPAT>
# F1-Score : 0.25
#
# INDEX 25
# Treneuil (de), bibliothécaire de la biblio-théque de l'arsenal, rue Sully.
# <PER>Treneuil (de),</PER><DESC><ACT> bibliothécaire</ACT> de la biblio-théque de l'arsenal</DESC>,<SPAT><LOC> rue Sully</LOC></SPAT><DESC>.</DESC>
# F1-Score : 0.25
#
# INDEX 26
# Bernard †.Ri Chabanois,"5.
# <PER>Bernard</PER> †.Ri<SPAT><LOC> Chabanois</LOC>,<CARDINAL>"5</CARDINAL></SPAT>.
# F1-Score : 0.25
#
# INDEX 27
# Gavarni, art.-peintre, au Point-du-Jour.
# <PER>Gavarni</PER><ACT>, art.-peintre</ACT>,<SPAT><LOC> au Point-du-Jour</LOC></SPAT><ACT>.</ACT>
# F1-Score : 0.25
#
# INDEX 28
# Bonnin, St-Dom.-St-Germ., 183.
# <PER>Bonnin</PER>,<SPAT><LOC> St-Dom.-St-Germ</LOC>.,<CARDINAL> 183.</CARDINAL></SPAT>
# F1-Score : 0.25
#
# INDEX 29
# Viget, bijout., orfév., horlog., St-Antoine, 201—203-205.
# <PER>Viget</PER><ACT>, bijout., orfév., horlog.</ACT><SPAT><LOC>, St-Antoine</LOC>,<CARDINAL> 201</CARDINAL>—<CARDINAL>203-2</CARDINAL></SPAT>05<ACT>.</ACT>
# F1-Score : 0.26666666666666666
#
# INDEX 30
# Vatry (de), representant du peuple (Meurthe),Notre-Dame-de-Lorette, 20.
# <PER>Vatry (de),</PER><DESC><ACT> represent</ACT></DESC><ACT>ant</ACT><DESC> du peuple (Meurthe</DESC><SPAT><LOC>),Notre-Dame-de-Lorette</LOC>,<CARDINAL> 20</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.28571428571428575
#
# INDEX 31
# —Boisgard, E. Montorguctl, to.
# —<PER>Boisgard</PER>,<SPAT><LOC> E. Montorguct</LOC>l,<CARDINAL> to</CARDINAL></SPAT>.
# F1-Score : 0.28571428571428575
#
# INDEX 32
# DeHIAIJUHHedve(RN DEHTeLEF
# <PER>DeHI</PER>AIJUHH<ACT>ed</ACT><SPAT><LOC>ve(RN DEHTe</LOC><CARDINAL>LEF</CARDINAL></SPAT>
# F1-Score : 0.28571428571428575
#
# INDEX 33
# Viguier, O. */8, inspect. général des études,Вас, 35.
# <PER>Viguier,<TITREH> O. */8</TITREH></PER><ACT>, inspect. général des études</ACT><SPAT><LOC>,Ва</LOC>с,<CARDINAL> 35</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.30769230769230765
#
# INDEX 34
# Vielle, limonadier, café de la Régence,place du Palais-National, rue St-Honoré,243.
# <PER>Vielle</PER><ACT>, limonadier, café</ACT><SPAT><LOC> de la Régence</LOC></SPAT>,<SPAT><LOC>place du Palais-National, rue St-Honoré</LOC>,<CARDINAL>243.</CARDINAL></SPAT>
# F1-Score : 0.30769230769230765
#
# INDEX 35
# Aucler (A.), mercerie et quincaill., dépôtd'aiguilles, Bourg-l'Abbé, 19 ancien 21.
# <PER>Aucler (A.),</PER><ACT> mercerie et quincaill., dépôtd'aiguilles</ACT><SPAT><LOC>, Bourg-l'Abbé</LOC>,<CARDINAL> 19</CARDINAL> ancien<CARDINAL> 21</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3076923076923077
#
# INDEX 36
# Lebègue (Mile Th.), successeur deM. Vallet, entrepreneur de mo-numents funebres, boul. Montpar-nasse, 64, près le cimetière duSud; monuments en pierre et enmarbres ; construction de caveauxet de chapelles ; sculpture, gra-vure d'inscriptions; grilles enfer, entourages et croix de bois ;entreprend, pour les bâtiments,les cheminées en marbre et enpierre; fontaines et dessus decommodes ;entretien de tombeauxet jardins à l'année ; caveau dedépôt pour inhumation provisoire ;fait des envois dans tous pays.
# <PER>Lebègue (Mile Th.), successeur deM. Vallet</PER><DESC>,<ACT> entrepreneur de mo-numents funebres</ACT></DESC>,<SPAT><LOC> boul. Montpar-nasse</LOC>,<CARDINAL> 64</CARDINAL>,<LOC> près le cimetière duSud</LOC></SPAT><DESC>;<ACT> monuments en pierre et enmarbres ; construction de caveauxet de chapelles ; sculpture, gra-vure d</ACT>'<ACT>inscriptions; grilles enfer, entourages et croix de bois</ACT> ;entreprend, pour les bâtiments,les<ACT> cheminée</ACT>s<ACT> en marbre et enpierre</ACT>;<ACT> fontaine</ACT>s<ACT> et dessus decommodes</ACT> ;entretien de tombeauxet jardins à l'année ; caveau dedépôt pour inhumation provisoire ;fait des envois dans tous pays.</DESC>
# F1-Score : 0.3076923076923077
#
# INDEX 37
# Darnet (D.), chemisier, Richelieu, 83, ancien33.
# <PER>Darnet (D.),</PER><ACT> chemisier</ACT><SPAT><LOC>, Richelieu</LOC>,<CARDINAL> 83</CARDINAL>, ancien<CARDINAL>33</CARDINAL>.</SPAT>
# F1-Score : 0.3076923076923077
#
# INDEX 38
# Association du Sablier ; marbrierset tailleurs de pierre réunis,pour les monuments funèbreset publics, ornements de pre-mier choix pour la sculpture surpierre et sur marbre, transportsdes corps en province et à l'é-tranger , Fontaine—St-Georges,46.
# <PER>Association du Sablier ;</PER><DESC><ACT> marbr</ACT></DESC><ACT>iers</ACT><DESC><ACT>et</ACT></DESC><ACT> t</ACT><PER>ailleurs</PER><DESC><ACT> de pierre</ACT></DESC><ACT> réunis,</ACT><DESC><ACT>pour les monuments funèbreset publics, ornements de pre-mier choix pour la sculpture surpierre et sur marbre, transports</ACT>des corps en province et à l'é-tranger</DESC> ,<SPAT><LOC> Fontaine—St-Georges</LOC>,<CARDINAL>46</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3157894736842105
#
# INDEX 39
# Courtois (Henry), maison Tam-ponnet, horticulteur, possesseurdes premiers camélias venus enFrance, et donnés à M. Tam-ponnet par l'impératrice José-phine, Muette, 16.
# <PER>Courtois (Henry),</PER><DESC> maison</DESC><PER> Tam</PER><DESC>-ponnet,<ACT> horticulteur, possesseurdes</ACT> premiers<ACT> camélias</ACT> venus enFrance, et donnés à M. Tam-ponnet par l'impératrice José-phine,</DESC><SPAT><LOC> Muette</LOC>,<CARDINAL> 16</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.3157894736842105
#
# INDEX 40
# Dargenton, chef de bureau au ministère del'Agriculture et du Commerce.
# <PER>Dargenton</PER><ACT>, chef de bureau au ministère del'Agriculture</ACT><DESC> et du Commerce</DESC><ACT>.</ACT>
# F1-Score : 0.3333333333333333
#
# INDEX 41
# Bontems, (Mad.) place du Pal.-Royal, 241.
# <PER>Bontems,</PER><ACT> (</ACT><PER>M</PER><ACT>ad</ACT><PER>.)</PER><SPAT><LOC> place du Pal.-Royal</LOC>,<CARDINAL> 241.</CARDINAL></SPAT>
# F1-Score : 0.3333333333333333
#
# INDEX 42
# Daubre Mme), artiste à l'Opéra, Blanche, 70.
# <PER>Daubre Mme),</PER><ACT> artiste</ACT><DESC> à l'Opéra</DESC><SPAT><LOC>, Blanche</LOC>,<CARDINAL> 70</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3333333333333333
#
# INDEX 43
# Vicillesse(hosp.de la), pour hommes, à Bicêtre.
# <PER>Vicillesse(hosp.de la),</PER><ACT> pour hommes</ACT>,<SPAT><LOC> à Bicêtre</LOC></SPAT><PER>.</PER>
# F1-Score : 0.3333333333333333
#
# INDEX 44
# Aubry — Foucault, gérant de la Gazette deFrance, Doyenné, 12.
# <PER>Aubry</PER> —<PER> Foucault</PER><ACT>, gérant de la Gazette deFrance</ACT><SPAT><LOC>, Doyenné</LOC>,<CARDINAL> 12</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3333333333333333
#
# INDEX 45
# Darondeau as, ingenieur hydrographe, Ouest,40.
# <PER>Darondeau<TITREH> a</TITREH></PER>s<ACT>, ingenieur hydrographe</ACT><SPAT><LOC>, Ouest</LOC>,<CARDINAL>40</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3333333333333333
#
# INDEX 46
# Vaux (Mme), enseignement mutuel, 1er ar-rondissement, Longchamps, 29.
# <PER>Vaux (Mme),</PER><DESC><ACT> enseignement mutuel</ACT>, 1er ar-rondissement</DESC><SPAT><LOC>, Longchamps</LOC>,<CARDINAL> 29</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.3333333333333333
#
# INDEX 47
# Audouard, courtier de comm., rue...
# <PER>Audouard</PER><ACT>, courtier de comm.</ACT>,<SPAT><LOC> rue...</LOC></SPAT>
# F1-Score : 0.3333333333333333
#
# INDEX 48
# —Bourguignon freresA-T-ELDITES, i—R. Notre-DanS
# —<PER>Bourguignon freres</PER>A-<PER>T-ELDITES</PER>, i—<SPAT><LOC>R. Notre-DanS</LOC></SPAT>
# F1-Score : 0.3333333333333333
#
# INDEX 49
# Vauvilliers (E. ), préparateur au baccalauréat,Maçons-Sorbonne, 17.
# <PER>Vauvilliers (E. ),</PER><DESC><ACT> préparateur</ACT> au baccalauréat</DESC><SPAT><LOC>,Maçons-Sorbonne</LOC>,<CARDINAL> 17</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3333333333333333
#
# INDEX 50
# Rennit "et Pignard, RiN. Eganterdí.
# <PER>Rennit "et Pignard</PER>,<SPAT><LOC> RiN. Eganterd</LOC></SPAT>í.
# F1-Score : 0.3333333333333333
#
# INDEX 51
# Daris frères, peintres-vitriers, pass. du Sau-mon, maison XXVI.
# <PER>Daris frères</PER><ACT>, peintres-vitriers</ACT>,<SPAT><LOC> pass. du Sau-mon</LOC>, maison<CARDINAL> XXVI</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3636363636363636
#
# INDEX 52
# Gautier, morceaux de drap et literie, Tonnel-leriè, 33.
# <PER>Gautier</PER><ACT>, morceaux de drap et literie</ACT><SPAT><LOC>, Tonnel-leri</LOC>è,<CARDINAL> 33</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3636363636363636
#
# INDEX 53
# Viennet (Mme, fab. de bas, Clichy, 13.
# <PER>Viennet (Mme</PER><ACT>, fab. de bas</ACT><SPAT><LOC>, Clichy</LOC>,<CARDINAL> 13</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3636363636363636
#
# INDEX 54
# Gaut (Mme, reperceuse, Pastourelle, 32.
# <PER>Gaut (Mme</PER><ACT>, reperceuse</ACT><SPAT><LOC>, Pastourelle</LOC>,<CARDINAL> 32</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3636363636363636
#
# INDEX 55
# Dasset, propriet., Bleue, 3 bts.
# <PER>Dasset</PER><ACT>, propriet.</ACT><SPAT><LOC>, Bleue</LOC>,<CARDINAL> 3 b</CARDINAL></SPAT>ts<ACT>.</ACT>
# F1-Score : 0.3636363636363636
#
# INDEX 56
# Daumas (Mine), sage-femme, Saint-Jacques,JS.
# <PER>Daumas (Mine),</PER><ACT> sage-femme</ACT><SPAT><LOC>, Saint-Jacques</LOC>,<CARDINAL>J</CARDINAL></SPAT>S<ACT>.</ACT>
# F1-Score : 0.3636363636363636
#
# INDEX 57
# Dauphin (Mlle, corsets, Poissonmere, 46.
# <PER>Dauphin (Mlle</PER><ACT>, corsets</ACT><SPAT><LOC>, Poissonmere</LOC>,<CARDINAL> 46</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.3636363636363636
#
# INDEX 58
# Vieille *, professeur agrégé à la Faculté dessciences, maître des conférences à l'Ecolena
# <PER>Vieille<TITREH> *</TITREH></PER><DESC><ACT>, professeur agrégé</ACT> à la Faculté dessciences,<ACT> maître</ACT> des<ACT> conférences</ACT> à l'Ecolena</DESC>
# F1-Score : 0.36363636363636365
#
# INDEX 59
# Vatimesnil (H. de) ,O. *, avocat à la courd'appel, représentant du peuple (Eure), St-Dominique-St-Germain, 11.
# <PER>Vatimesnil (H. de) ,<TITREH>O. *</TITREH></PER><DESC><ACT>, avocat</ACT> à la courd'appel,<ACT> représentant</ACT> du peuple (Eure</DESC><SPAT><LOC>), St-Dominique-St-Germain</LOC>,<CARDINAL> 11</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.37499999999999994
#
# INDEX 60
# Bourrousse fils aîné, fab. de fon-taines filtrantes en pierre et enmarbre, fait la fourniture detoutes sortes de pierres taillées,tant pour le bâtiment que pourtravaux hydrauliques ; fait éga-lement la marbrerie, tant pourmeubles et bâtiments que pourmonuments funèbres. Fait tou—tes sortes de carrelages en liaiset en marbres , mosaïques, dal-lages, etc.; fontaines en gros,en pierre et en marbre, commis-sion en marbrerie, Ste-Avoye,59, hôtel St-Aignan.
# <PER>Bourrousse fils aîné</PER><DESC><ACT>, fab. de fon-taines filtrantes en pierre et enmarbre, fait</ACT> la<ACT> fourniture detoutes sortes de pierres taillées</ACT>,tant<ACT> pour le bâtiment</ACT> que<ACT> pourtravaux hydraulique</ACT>s ; fait éga-lement la<ACT> marbre</ACT>rie, tant pourmeubles et bâtiments que pour<ACT>monuments</ACT> funèbres.<ACT> Fait tou—tes sortes de carrelages en liaiset en marbres , mosaïques, dal-lages, etc.; fontaines en gros,en pierre et en marbre, commis-sion en marbre</ACT></DESC><ACT>rie</ACT>,<SPAT><LOC> Ste-Avoye</LOC>,<CARDINAL>59</CARDINAL>,<LOC> hôtel St-Aignan</LOC></SPAT><ACT>.</ACT>
# F1-Score : 0.3870967741935483
#
# INDEX 61
# Cels frères, horticulleurs, chaus-see du Maine. 77; collection decaclées, orchidées, camélias, pal-miers et végétaux exotiques detoutes les partiës du globe, 6 mé-dailles d'or, 18 médailles d'ar-gent de diverses Sociétés d'horti-culture,  1849, exportation pourla France et l'étranger.
# <PER>Cels frères</PER><DESC><ACT>, horticulleurs</ACT></DESC>,<SPAT><LOC> chaus-see du Maine</LOC>.<CARDINAL> 77</CARDINAL></SPAT>;<DESC><ACT> collection decaclées, orchidées, camélias, pal-miers et végétaux exotiques detoutes les partiës du globe, 6 mé-dailles d'</ACT>or, 18 médailles d'ar-gent de diverses Sociétés d<ACT>'</ACT>horti-culture,  1849, exportation pourla France et l'étranger.</DESC>
# F1-Score : 0.39999999999999997
#
# INDEX 62
# Gauthier, jardinier-fleuriste, av. Suffren, 20.
# <PER>Gauthier</PER><ACT>, jardinier-fleuriste</ACT>,<SPAT><LOC> av. Suffren</LOC>,<CARDINAL> 20</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4
#
# INDEX 63
# Gavarret, représentant du peuple (Gers), Gre-nelle-St-Germain, 89.
# <PER>Gavarret</PER><ACT>, représentant du peuple</ACT><DESC> (</DESC><ACT>G</ACT><DESC>ers</DESC><SPAT><LOC>), Gre-nelle-St-Germain</LOC>,<CARDINAL> 89</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4
#
# INDEX 64
# Auclerc, sous-chef de bureau à la prefecturede police.
# <PER>Auclerc</PER><ACT>, sous-chef de bureau à la prefecturede police.</ACT>
# F1-Score : 0.4
#
# INDEX 65
# Vaulabelle, conservat. du cimetière du Nord(Montmartre).
# <PER>Vaulabelle</PER><ACT>, conservat. du</ACT><SPAT><LOC> cimetière du Nord(Montmartre).</LOC></SPAT>
# F1-Score : 0.4
#
# INDEX 66
# Lebegue frères (ancienne maisonDuriez), entrepreneurs de monu-ments funèbres, Roquette, 200 ;entreprennent la constructiondes caveaux de famille, la sculp-ture et la gravure; ils expédientavec garantie pour les départe-ments et l'étranger, et se char-gent de la fourniture des grilleset entourages; caveaux de dépôtpour inhumations provisoires.
# <PER>Lebegue frères (ancienne maisonDuriez),</PER><DESC><ACT> entrepreneurs de monu-ments funèbres</ACT></DESC>,<SPAT><LOC> Roquette</LOC>,<CARDINAL> 200</CARDINAL></SPAT><DESC> ;entreprennent la constructiondes caveaux de famille, la sculp-ture et la<ACT> gravure</ACT>; ils expédientavec garantie pour les départe-ments et l'étranger, et se char-gent de la fourniture des grilleset entourages;<ACT> caveaux de dépôtpour inhumations provisoire</ACT>s.</DESC>
# F1-Score : 0.4
#
# INDEX 67
# Tousselot, Marche des Jacobins.
# <PER>Tousselot</PER><SPAT><LOC>, Marche des Jacobins</LOC></SPAT><ACT>.</ACT>
# F1-Score : 0.4
#
# INDEX 68
# Tuffet Saint-Martin, rue Jacob, 20.
# <PER>Tuffet</PER><DESC> Saint-Martin</DESC><SPAT><LOC>, rue Jacob</LOC>,<CARDINAL> 20</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.4
#
# INDEX 69
# Audemars (Louis), fab. d'horlogerie, repré-senté par Hector Audemars, St-Fiacre, 3.
# <PER>Audemars (Louis),</PER><DESC><ACT> fab. d</ACT>'<ACT>horlogerie</ACT>, repré-senté par Hector Audemars</DESC><SPAT><LOC>, St-Fiacre</LOC>,<CARDINAL> 3</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.4
#
# INDEX 70
# Aubé frères, (droguistes) R. des Lomhards, o.
# <PER>Aubé frères</PER><ACT>, (droguistes)</ACT><SPAT><LOC> R. des Lomhards</LOC>,<CARDINAL> o</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4
#
# INDEX 71
# Dauge (P.), dépòt de papiers, Blancs-Man-teaux. 35.
# <PER>Dauge (P.),</PER><ACT> dépòt de papiers</ACT><SPAT><LOC>, Blancs-Man-teaux</LOC>.<CARDINAL> 35</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4
#
# INDEX 72
# Chardin et comp., fabr. de boutons demétal artimomantico, par brevet din-vention, à Vaugirard.
# <PER>Chardin et comp.</PER><DESC><ACT>, fabr. de boutons demétal artimomantico</ACT>, par brevet din-vention</DESC>,<DESC> à</DESC><SPAT><LOC> Vaugirard</LOC></SPAT><DESC>.</DESC>
# F1-Score : 0.4
#
# INDEX 73
# Aubry (Mme), garnitures de bourses, Berry(Marais), 13.
# <PER>Aubry (Mme),</PER><ACT> garnitures de bourses</ACT><SPAT><LOC>, Berry(Marais</LOC>),<CARDINAL> 13</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4
#
# INDEX 74
# Viel, agent général du bureau du charbon debois et gérant de l'école de natation Henri IV,Bretonvilliers, 1.
# <PER>Viel</PER><ACT>, agent général du bureau du charbon debois et gérant de l'école de natation</ACT><DESC> Henri IV</DESC><SPAT><LOC>,Bretonvilliers</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4
#
# INDEX 75
# Aubrée, horloger, St-Honoré, 134.
# <PER>Aubrée</PER><ACT>, horloger</ACT><SPAT><LOC>, St-Honoré</LOC>,<CARDINAL> 134.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 76
# VasseurMlle,jouets, Bac, 101
# <PER>VasseurMlle</PER><ACT>,jouets</ACT><SPAT><LOC>, Bac</LOC>,<CARDINAL> 101</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 77
# Daunard, jardinier- fleuriste, Vaugirard, 204.
# <PER>Daunard</PER><ACT>, jardinier- fleuriste</ACT><SPAT><LOC>, Vaugirard</LOC>,<CARDINAL> 204.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 78
# Vié, fab. de bonneterie, St-Jacques, 161.
# <PER>Vié</PER><ACT>, fab. de bonneterie</ACT><SPAT><LOC>, St-Jacques</LOC>,<CARDINAL> 161.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 79
# Aubry, coutelier, Vieille-du-Temple, 131.
# <PER>Aubry</PER><ACT>, coutelier</ACT><SPAT><LOC>, Vieille-du-Temple</LOC>,<CARDINAL> 131.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 80
# —Termot—Čaros. J. R. Joubert, 32,
# —<PER>Termot</PER>—<ACT>Čaros</ACT>. J<SPAT><LOC>. R. Joubert</LOC>,<CARDINAL> 32</CARDINAL></SPAT>,
# F1-Score : 0.4000000000000001
#
# INDEX 81
# Gautrin, maraicher, St-Maur-Popincourt, 224.
# <PER>Gautrin</PER><ACT>, maraicher</ACT><SPAT><LOC>, St-Maur-Popincourt</LOC>,<CARDINAL> 224.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 82
# Vaugeois (Mlles), broderies, St-Honoré, 371.
# <PER>Vaugeois (Mlles),</PER><ACT> broderies</ACT><SPAT><LOC>, St-Honoré</LOC>,<CARDINAL> 371.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 83
# Vasseur, laine et tapis, St-Honoré, 262.
# <PER>Vasseur</PER><ACT>, laine et tapis</ACT><SPAT><LOC>, St-Honoré</LOC>,<CARDINAL> 262.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 84
# Dastugue, epicier, Faub.-St-Martin, 162.
# <PER>Dastugue</PER><ACT>, epicier</ACT><SPAT><LOC>, Faub.-St-Martin</LOC>,<CARDINAL> 162.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 85
# Vildé, chapelier, St-Dominique, 161.
# <PER>Vildé</PER><ACT>, chapelier</ACT><SPAT><LOC>, St-Dominique</LOC>,<CARDINAL> 161.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 86
# —Gavillon, maréchal-expert, Vaugirard, 143.
# —<PER>Gavillon</PER><ACT>, maréchal-expert</ACT><SPAT><LOC>, Vaugirard</LOC>,<CARDINAL> 143.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 87
# Vilatte, pharmacien, St-Honoré, 232.
# <PER>Vilatte</PER><ACT>, pharmacien</ACT><SPAT><LOC>, St-Honoré</LOC>,<CARDINAL> 232.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 88
# Viguier, chapelier, St-Honoré, 131.
# <PER>Viguier</PER><ACT>, chapelier</ACT><SPAT><LOC>, St-Honoré</LOC>,<CARDINAL> 131.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 89
# Daube père, jardinier-fleuriste, Charonne, 164.
# <PER>Daube père</PER><ACT>, jardinier-fleuriste</ACT><SPAT><LOC>, Charonne</LOC>,<CARDINAL> 164.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 90
# Vignon, Cte de Servasca, Lamartine, 34.
# <PER>Vignon, Cte de Servasca</PER><SPAT><LOC>, Lamartine</LOC>,<CARDINAL> 34</CARDINAL></SPAT><PER>.</PER>
# F1-Score : 0.4000000000000001
#
# INDEX 91
# Guerin fils, entrepreneur de mo-numents funèbres, Roquette,181.
# <PER>Guerin fils</PER><ACT>, entrepreneur de mo-numents funèbres</ACT><SPAT><LOC>, Roquette</LOC>,<CARDINAL>181.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 92
# Daubancourt, horloger, St-Lazare, 121.
# <PER>Daubancourt</PER><ACT>, horloger</ACT><SPAT><LOC>, St-Lazare</LOC>,<CARDINAL> 121.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 93
# Gavot, vins, Faub.-St-Antoine, 133.
# <PER>Gavot</PER><ACT>, vins</ACT><SPAT><LOC>, Faub.-St-Antoine</LOC>,<CARDINAL> 133.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 94
# Gautier aîné, gainier, Grenétat, I I,
# <PER>Gautier aîné</PER><ACT>, gainier</ACT><SPAT><LOC>, Grenétat</LOC>,<CARDINAL> I I</CARDINAL></SPAT>,
# F1-Score : 0.4000000000000001
#
# INDEX 95
# Datry,passementier, St-Denis, 173.
# <PER>Datry</PER><ACT>,passementier</ACT><SPAT><LOC>, St-Denis</LOC>,<CARDINAL> 173.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 96
# Lecomte, monuments funèbres,Roquette, 163.
# <PER>Lecomte</PER><ACT>, monuments funèbres</ACT><SPAT><LOC>,Roquette</LOC>,<CARDINAL> 163.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 97
# Vigerie (L.) ainé, parfumeur, St-Denis, 243.
# <PER>Vigerie (L.) ainé</PER><ACT>, parfumeur</ACT><SPAT><LOC>, St-Denis</LOC>,<CARDINAL> 243.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 98
# Vildieu, vins, St-Denis, 232.
# <PER>Vildieu</PER><ACT>, vins</ACT><SPAT><LOC>, St-Denis</LOC>,<CARDINAL> 232.</CARDINAL></SPAT>
# F1-Score : 0.4000000000000001
#
# INDEX 99
# Aucler, de la maison Surmont et Aucler, Sen-tier, 31.
# <PER>Aucler, de la maison Surmont et Aucler</PER><SPAT><LOC>, Sen-tier</LOC>,<CARDINAL> 31</CARDINAL></SPAT><PER>.</PER>
# F1-Score : 0.4000000000000001
#
# INDEX 100
# Tripet Vve) et Leblanc, grainiers-fleuristes et pépinieristes, b. desCapucines, 21 (AU CAPOUSTA),cultures r. Bizet, 27 (Champs-Elysées), graines de toutes es-pèces, potagères, de fleurs, degazon de prairie, d'arbres, d'ar-bustes et d'arbrisseaux, toutesespèces d'oignons à fleurs, ané-mones, jacinthes, renoncules, tu-lipes par noms et coul urs et enmélange, et melange de ces qua-tre plantes bulbeuses, arbres àfruits, arbres, arbustes et arbris-seaux d'utilité et d'ornement,rosiers, dahlias, oeillets, plantesvivaces, etc.;  Société horti-culture 1838, 1839, 1840, 1841,1842, O 1843 et 1844; prixd'honneur fondé par la duchessed'Orleans.
# <PER>Tripet Vve) et Leblanc</PER><DESC><ACT>, grainiers-fleuristes et pépinieristes</ACT></DESC>,<SPAT><LOC> b. desCapucines</LOC>,<CARDINAL> 21</CARDINAL></SPAT> (AU<DESC> CAPOUSTA),</DESC>cultures<SPAT><LOC> r. Bizet</LOC>,<CARDINAL> 27</CARDINAL></SPAT> (<SPAT><LOC>Champs-Elysées</LOC></SPAT><DESC>),<ACT> graines de toutes es-pèces, potagères, de fleurs, degazon de prairie, d'arbres, d'ar-bustes et d'arbrisseaux, toutesespèces d'oignons à fleurs, ané-mones, jacinthes, renoncules, tu-lipes par noms et coul urs et enmélange, et melange de ces qua-tre plantes bulbeuses, arbres àfruits, arbres, arbustes et arbris-seaux d'utilité et d'ornement,rosiers, dahlias, oeillets, plantesvivaces, etc.</ACT></DESC>;<DESC><TITREP> Société</TITREP> horti-<TITREP>culture 1838, 1839, 1840, 1841,1842, O 1843 et 1844</TITREP>; prixd<ACT>'</ACT>honneur fondé par la duchessed'Orleans<ACT>.</ACT></DESC>
# F1-Score : 0.4117647058823529
#
# INDEX 101
# Paillard (J.-M.), successeur deJ. Panier, mannequins et ma-quelles de toutes sortes, Pariset façon de Paris,  1844,Francs-Bourgeois-Marais, 21.
# <PER>Paillard (J.-M.), successeur deJ. Panier</PER><DESC><ACT>, mannequins et ma-quelles de toutes sortes, Pariset façon de Paris</ACT><TITREP>,  1844</TITREP></DESC><SPAT><LOC>,Francs-Bourgeois-Marais</LOC>,<CARDINAL> 21</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.42857142857142855
#
# INDEX 102
# Aubry-Lapied, tourneur, Gravilliers, 28,cour de Rome.
# <PER>Aubry-Lapied</PER><ACT>, tourneur</ACT><SPAT><LOC>, Gravilliers</LOC>,<CARDINAL> 28</CARDINAL><LOC>,cour de Rome</LOC></SPAT><ACT>.</ACT>
# F1-Score : 0.42857142857142855
#
# INDEX 103
# baints-Peres, .Aubertin, représentant du peuple (Marne),Richelieu, 63.
# <PER>baints-Peres,</PER> <PER>.Aubertin</PER><ACT>, représentant du peuple</ACT><DESC> (Marne</DESC><SPAT><LOC>),Richelieu</LOC>,<CARDINAL> 63</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.42857142857142855
#
# INDEX 104
# Vauvilliers i, avocat à la cour d'appel, Fer-me, 34 bis.
# <PER>Vauvilliers<TITREH> i</TITREH></PER><DESC><ACT>, avocat</ACT> à la cour d'appel</DESC><SPAT><LOC>, Fer-me</LOC>,<CARDINAL> 34 bis</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.42857142857142855
#
# INDEX 105
# Dauchez (Amedée), avocat, agent du canald'Aire à la Bassée, St-Guillaume, 12.
# <PER>Dauchez (Amedée),</PER><DESC><ACT> avocat</ACT>,<ACT> agent</ACT> du canald'Aire à la Bassée</DESC>,<SPAT><LOC> St-Guillaume</LOC>,<CARDINAL> 12</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.42857142857142855
#
# INDEX 106
# Vienot (Gustave), caissier de la compagnienationale d'assurances sur la vie, Ménars, 3.
# <PER>Vienot (Gustave),</PER><DESC><ACT> caissier</ACT> de la compagnienationale d</DESC><ACT>'</ACT><DESC><ACT>assurances sur la vie</ACT></DESC>,<SPAT><LOC> Ménars</LOC>,<CARDINAL> 3</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.42857142857142855
#
# INDEX 107
# Viguier, représentant du peuple (Cher), Ar-bre-Sec, 44.
# <PER>Viguier</PER><ACT>, représentant du peuple</ACT><DESC> (</DESC><ACT>Ch</ACT><DESC>er</DESC><SPAT><LOC>), Ar-bre-Sec</LOC>,<CARDINAL> 44</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.42857142857142855
#
# INDEX 108
# Vignes (Th.), représentant du peuple (Arié-ge), Faub. -St-Honoré, 100.
# <PER>Vignes (Th.),</PER><ACT> représentant du peuple</ACT><DESC> (A</DESC><ACT>rié-ge),</ACT><SPAT><LOC> Faub. -St-Honoré</LOC>,<CARDINAL> 100</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.42857142857142855
#
# INDEX 109
# Daumas , C. a/4, général de brigade, chef duservice de l'Algerie au ministère de la guerre,Beaune, 14.
# <PER>Daumas ,<TITREH> C. a/4</TITREH></PER><ACT>,</ACT><DESC><ACT> général de</ACT></DESC><ACT> brigade</ACT><DESC><ACT>, chef duservice</ACT></DESC><ACT> de l'Algerie</ACT><DESC> au ministère de la guerre</DESC>,<SPAT><LOC>Beaune</LOC>,<CARDINAL> 14</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4444444444444444
#
# INDEX 110
# Gauthier s, architecte du gouvernement,membre de l'Institut, St-Georges, 5.
# <PER>Gauthier</PER> s<ACT>,</ACT><DESC><ACT> architecte</ACT></DESC><ACT> du</ACT><DESC> gouvernement,</DESC><ACT>membre de</ACT><DESC> l</DESC><ACT>'Institut</ACT>,<SPAT><LOC> St-Georges</LOC>,<CARDINAL> 5</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4444444444444444
#
# INDEX 111
# Thibault-Prudent, arbres frui-tiers, forestiers et d'agrément,graines potagères, de fleurs me-dicinales, fourragères, de grandeculture, expédie pour la Franceet l'étranger, rue de la Ferron-nerie, 11, près le marché des In-nocents, à la Cloche des hallesaux legumes.
# <PER>Thibault-Prudent</PER><DESC><ACT>, arbres frui-tiers, forestiers et d'agrément,graines potagères, de fleurs me-dicinales, fourragères, de grandeculture,</ACT> expédie pour la Franceet l</DESC><ACT>'</ACT><DESC>étranger</DESC>,<SPAT><LOC> rue de la Ferron-nerie</LOC>,<CARDINAL> 11</CARDINAL><LOC>, près le marché des In-nocents, à la Cloche des hallesaux legumes</LOC></SPAT><ACT>.</ACT>
# F1-Score : 0.4444444444444445
#
# INDEX 112
# Aubin, imprimeur en taille-douce, Caire, 1.
# <PER>Aubin</PER><ACT>, imprimeur en taille-douce</ACT><SPAT><LOC>, Caire</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 113
# Vautré (Vve Bonne deBourgogne, 50.
# <PER>Vautré (Vve</PER><SPAT><LOC> Bonne deBourgogne</LOC>,<CARDINAL> 50</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4444444444444445
#
# INDEX 114
# Vasseur, limonadier, Londres, 1.
# <PER>Vasseur</PER><ACT>, limonadier</ACT><SPAT><LOC>, Londres</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 115
# Vignon, épicier, Sept-Voies, 1.
# <PER>Vignon</PER><ACT>, épicier</ACT><SPAT><LOC>, Sept-Voies</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 116
# Villain, architecte, Bourdaloue,1.
# <PER>Villain</PER><ACT>, architecte</ACT><SPAT><LOC>, Bourdaloue</LOC>,<CARDINAL>1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 117
# Gautron, coiffeur, Savonnerie, 1.
# <PER>Gautron</PER><ACT>, coiffeur</ACT><SPAT><LOC>, Savonnerie</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 118
# Conard, St-Dom.-St-Germ., 217.
# <PER>Conard</PER>,<SPAT><LOC> St-Dom.-St-Germ</LOC>.,<CARDINAL> 217</CARDINAL><LOC>.</LOC></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 119
# Gaveau, serrurier en batiments, Courcelles,1.
# <PER>Gaveau</PER><ACT>, serrurier en batiments</ACT><SPAT><LOC>, Courcelles</LOC>,<CARDINAL>1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 120
# Neveu, Amandiers-Popinc., 38.
# <PER>Neveu</PER>,<SPAT><LOC> Amandiers-Popinc</LOC>.,<CARDINAL> 38</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4444444444444445
#
# INDEX 121
# Vasselin, ébeniste, Frochot, 1.
# <PER>Vasselin</PER><ACT>, ébeniste</ACT><SPAT><LOC>, Frochot</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 122
# Rapp. de la Clef, 37.
# <PER>R</PER><SPAT><LOC>app. de la Clef</LOC>,<CARDINAL> 37</CARDINAL><LOC>.</LOC></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 123
# Rouveau, Amandiers-Popinc., 29.
# <PER>Rouveau</PER>,<SPAT><LOC> Amandiers-Popinc</LOC>.,<CARDINAL> 29</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4444444444444445
#
# INDEX 124
# Vielle, vins fins et ordinaires, St-André-des-Arts, 1.
# <PER>Vielle</PER><ACT>, vins fins et ordinaires</ACT><SPAT><LOC>, St-André-des-Arts</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 125
# Vasseur, vins, boul. de l'Hôpital, 1.
# <PER>Vasseur</PER><ACT>, vins</ACT><SPAT><LOC>, boul. de l'Hôpital</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 126
# Aubry, serrurier, N.-D.-de-Nazareth, 1.
# <PER>Aubry</PER><ACT>, serrurier</ACT><SPAT><LOC>, N.-D.-de-Nazareth</LOC>,<CARDINAL> 1.</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 127
# Bellière, R. de In Libertě. 55.
# <PER>Bellière</PER>,<SPAT><LOC> R. de In Libert</LOC>ě.<CARDINAL> 55</CARDINAL><LOC>.</LOC></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 128
# DIÉSOR*R. S. André-des-Aris*— —*
# <PER>DIÉSOR</PER>*<SPAT><LOC>R. S. André-des-Aris</LOC>*—<CARDINAL> —</CARDINAL><LOC>*</LOC></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 129
# NHertrand1H. S. Martin,I
# N<PER>Hertrand</PER><ACT>1</ACT><SPAT><LOC>H. S. Martin</LOC>,<CARDINAL>I</CARDINAL></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 130
# Chauvin, R. Thibauthode.If.
# <PER>Chauvin</PER>,<SPAT><LOC> R. Thibauthode</LOC>.<CARDINAL>I</CARDINAL><LOC>f.</LOC></SPAT>
# F1-Score : 0.4444444444444445
#
# INDEX 131
# Dartigues &§, propriet., Tronchet, 3.
# <PER>Dartigues<TITREH> &amp;§</TITREH></PER><ACT>, propriet.</ACT><SPAT><LOC>, Tronchet</LOC>,<CARDINAL> 3</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4615384615384615
#
# INDEX 132
# Dartois, C. 2/4 , genéral de brigade, Varen-nes, 38.
# <PER>Dartois,<TITREH> C. 2/4</TITREH></PER> <ACT>, genéral de brigade</ACT><SPAT><LOC>, Varen-nes</LOC>,<CARDINAL> 38</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4615384615384615
#
# INDEX 133
# Vienne, inspecteur au chemin de fer du Nord,Lafayette, 52.
# <PER>Vienne</PER><ACT>, </ACT><DESC><ACT>inspecteur</ACT> au chemin de fer du Nord</DESC><SPAT><LOC>,Lafayette</LOC>,<CARDINAL> 52</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4615384615384615
#
# INDEX 134
# Auburtin père, fab. de cuirs vernis, barrièredes Deux-Moulins, rue des Rentiers, 35.
# <PER>Auburtin père</PER><ACT>, fab. de cuirs vernis</ACT>,<SPAT><LOC> barrièredes Deux-Moulins, rue des Rentiers</LOC>,<CARDINAL> 35</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4615384615384615
#
# INDEX 135
# Aubin, artificier, Lafayette, 113, en face la rueChâteau-Landon.
# <PER>Aubin</PER><ACT>, artificier</ACT><SPAT><LOC>, Lafayette</LOC>,<CARDINAL> 113</CARDINAL><LOC>, en face la rueChâteau-Landon.</LOC></SPAT>
# F1-Score : 0.4615384615384615
#
# INDEX 136
# Dariste, représentant du peuple ( Basses-Py-renées), Ferme, 26.
# <PER>Dariste</PER><ACT>, représentant du peuple</ACT><DESC> (</DESC><SPAT><LOC> Basses-Py-renées), Ferme</LOC>,<CARDINAL> 26</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.4615384615384615
#
# INDEX 137
# Vigla �§, médecin, Vieux-Colombier, 3.
# <PER>Vigla <TITREH>�§</TITREH></PER><ACT>, médecin</ACT><SPAT><LOC>, Vieux-Colombier</LOC>,<CARDINAL> 3</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.4615384615384615
#
# INDEX 138
# Marga (Eug.), (ancienne maisonMarga et fils), sculpteur- mar-brier; cheminées, autels, tombesde tout style, pour Paris et la pro-vince, fait l'exportation, boul. desFilles du-Calvaire, 5.
# <PER>Marga (Eug.), (ancienne maisonMarga et fils),</PER><DESC><ACT> sculpteur- mar-brier; cheminées, autels, tombesde tout style, pour</ACT> Paris et la pro-vince, fait l'exportation</DESC>,<SPAT><LOC> boul. desFilles du-Calvaire</LOC>,<CARDINAL> 5</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.4615384615384615
#
# INDEX 139
# Audiffred, juge suppl. au tribunal de com-merce, Bons-Enfants, 26.
# <PER>Audiffred</PER><DESC><ACT>, juge suppl</ACT>. au tribunal de com-merce</DESC><SPAT><LOC>, Bons-Enfants</LOC>,<CARDINAL> 26</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.4615384615384615
#
# INDEX 140
# Bouillerot S.-Ange, r. de Loursine, 10.
# <PER>Bouillerot</PER><DESC> S</DESC><ACT>.</ACT><DESC>-</DESC><ACT>Ange</ACT>,<SPAT><LOC> r. de Loursine</LOC>,<CARDINAL> 10</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.46153846153846156
#
# INDEX 141
# Bontems,(Mad.) r. Hauteville, 37.
# <PER>Bontems,</PER><ACT>(</ACT><PER>M</PER><ACT>ad</ACT><PER>.)</PER><SPAT><LOC> r. Hauteville</LOC>,<CARDINAL> 37</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.46153846153846156
#
# INDEX 142
# Dubuisson,(Mad.) r. S.-Severin, 30.
# <PER>Dubuisson,</PER><ACT>(</ACT><PER>M</PER><ACT>ad</ACT><PER>.)</PER><SPAT><LOC> r. S.-Severin</LOC>,<CARDINAL> 30</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.46153846153846156
#
# INDEX 143
# Pépin, (Mad.) r. Marceau, 24.
# <PER>Pépin,</PER><ACT> (</ACT><PER>M</PER><ACT>ad</ACT><PER>.)</PER><SPAT><LOC> r. Marceau</LOC>,<CARDINAL> 24</CARDINAL></SPAT><ACT>.</ACT>
# F1-Score : 0.46153846153846156
#
# INDEX 144
# Touvais, successeur de Roblin,horticulteur-commerçant, culturespéciale de rosiers, dahlias et di-verses plantes de choix, pots àfleurs et bouquets à main pourfètes, Notre-Dame-des-Champs,85, ci-devant 47, pres du Luxem-bourg.
# <PER>Touvais, successeur de Roblin</PER><ACT>,horticulteur-commerçant, culturespéciale de rosiers, dahlias et di-verses plantes de choix, pots àfleurs et bouquets à main pourfètes</ACT>,<SPAT><LOC> Notre-Dame-des-Champs</LOC>,<CARDINAL>85</CARDINAL></SPAT>, ci-<SPAT><LOC>devant 47, pres du Luxem-bourg</LOC></SPAT><ACT>.</ACT>
# F1-Score : 0.47058823529411764
#
# INDEX 145
# Jacquin aîné et Cie, gramiers,fleuristes et pépiniéristes; com-merce en gros et en détail degraines potagères et fourragè-res, graines de fleurs et d'ar-bres, oignons à fleurs et planteset arbres de tous genres ; au BonJardinier, quai de la Mégisse-rie, 14. Cultures expérimentales,au Grand-Charonne, route deBagnolet, 20, près Paris; mé-dailles d'or et d'argent des di-verses societés horticoles.
# <PER>Jacquin aîné et Cie</PER><DESC><ACT>, gramiers,fleuristes et pépiniéristes</ACT>;<ACT> com-merce en gros et en détail degraines potagères et fourragè-res, graines de fleurs et d'ar-bres, oignons à fleurs et planteset arbres de tous genres</ACT></DESC> ;<DESC> au BonJardinier,</DESC><SPAT><LOC> quai de la Mégisse-</LOC></SPAT><DESC>rie</DESC><SPAT>,<CARDINAL> 14</CARDINAL></SPAT><DESC>. Cultures expérimentales,au Grand-Charonne,</DESC><SPAT><LOC> route deBagnolet</LOC>,<CARDINAL> 20</CARDINAL>,<LOC> près Paris</LOC></SPAT><DESC>; mé<ACT>-d</ACT>ailles d'or<ACT> et</ACT> d'argent des di-verses societés horticoles.</DESC>
# F1-Score : 0.47058823529411764
#
# INDEX 146
# Cherion, ſabric. de pinceaux, fournit�'Ecole impériale poly technique, lesdifférentes administrations et bureauxde S. M. l'Empereur et Roi, quai del'Horloge-du-Palais, 61.
# <PER>Cherion</PER><DESC><ACT>, ſabric. de pinceaux, fournit�'Ecole impériale poly technique</ACT>,<ACT> les</ACT>différentes administrations<ACT> et bureaux</ACT>de S. M. l'Empereur et Roi</DESC>,<SPAT><LOC> quai del'Horloge-du-Palais</LOC>,<CARDINAL> 61</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.4705882352941177
#
# INDEX 147
# Audiguier, correcteur à l'Imprimerie nation. ,Filles-du Calvaire, 6.
# <PER>Audiguier</PER><DESC><ACT>, correcteur</ACT> à l'Imprimerie nation.</DESC> <SPAT><LOC>,Filles-du Calvaire</LOC>,<CARDINAL> 6</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.5
#
# INDEX 148
# MPR. . Germain-l Aunerroj4 12.
# <PER>MP</PER><SPAT><LOC>R. . Germain-l Aunerro</LOC>j4<CARDINAL> 12</CARDINAL><LOC>.</LOC></SPAT>
# F1-Score : 0.5
#
# INDEX 149
# Viet, anc. économe à la Banque de France,St-Lazare, 66.
# <PER>Viet</PER><DESC><ACT>, anc. économe</ACT> à la Banque de France</DESC><SPAT><LOC>,St-Lazare</LOC>,<CARDINAL> 66</CARDINAL></SPAT><DESC>.</DESC>
# F1-Score : 0.5

# %% [markdown]
# ### 15-Top best

# %%
rdf = df.sort_values(by='f1', ascending=False)
for i in range(0,16):
    print(rdf.iloc[i]["entry"])
    print(rdf.iloc[i]["entry_xml"])
    print(f"F1-Score : {rdf.iloc[i]['f1']}")
    print("")
# Out:
# Vigier(baronne de"Rivoli, 30
# <PER>Vigier(baronne de</PER>"<SPAT><LOC>Rivoli</LOC>,<CARDINAL> 30</CARDINAL></SPAT>
# F1-Score : 1.0
#
# Valleville, rue Serv ndoni, 17.
# <PER>Valleville</PER>,<SPAT><LOC> rue Serv ndoni</LOC>,<CARDINAL> 17</CARDINAL></SPAT>.
# F1-Score : 1.0
#
# Bouillac, r. d'Amboise, 9
# <PER>Bouillac</PER>,<SPAT><LOC> r. d'Amboise</LOC>,<CARDINAL> 9</CARDINAL></SPAT>
# F1-Score : 1.0
#
# ☞2Duhamel, Bnufousa et comp. Rue S.Dentiš ráh=
# ☞2<PER>Duhamel, Bnufousa et comp.</PER><SPAT><LOC> Rue S.Dentiš</LOC> r<CARDINAL>áh</CARDINAL></SPAT>=
# F1-Score : 1.0
#
# Robert, R. Bergère, 19.
# <PER>Robert</PER>,<SPAT><LOC> R. Bergère</LOC>,<CARDINAL> 19</CARDINAL></SPAT>.
# F1-Score : 1.0
#
# Béziade-Davaray, rue de Grenelle-Saint-Germain, 85.
# <PER>Béziade-Davaray</PER>,<SPAT><LOC> rue de Grenelle-Saint-Germain</LOC>,<CARDINAL> 85</CARDINAL></SPAT>.
# F1-Score : 1.0
#
# Viguet (M.-L.) X, N.-D.-de-Lorette, 40.
# <PER>Viguet (M.-L.)<TITREH> X</TITREH></PER>,<SPAT><LOC> N.-D.-de-Lorette</LOC>,<CARDINAL> 40</CARDINAL></SPAT>.
# F1-Score : 1.0
#
# Hermon-Bonmard ocomp. Gétoffes)R. S: Denis ,15.☞
# <PER>Hermon-Bonmard ocomp.</PER><ACT> Gétoffes)</ACT><SPAT><LOC>R. S: Denis</LOC> ,<CARDINAL>15.</CARDINAL></SPAT>☞
# F1-Score : 1.0
#
# Vaudreuil(CsseCaumartin, 44
# <PER>Vaudreuil(Csse</PER><SPAT><LOC>Caumartin</LOC>,<CARDINAL> 44</CARDINAL></SPAT>
# F1-Score : 1.0
#
# Bockairy, r. Croix-des-Petits-Champs, 23.
# <PER>Bockairy</PER>,<SPAT><LOC> r. Croix-des-Petits-Champs</LOC>,<CARDINAL> 23</CARDINAL></SPAT>.
# F1-Score : 1.0
#
# Barbier, Roquette,166
# <PER>Barbier</PER>,<SPAT><LOC> Roquette</LOC>,<CARDINAL>166</CARDINAL></SPAT>
# F1-Score : 1.0
#
# Chauvois, Roquette, 163
# <PER>Chauvois</PER>,<SPAT><LOC> Roquette</LOC>,<CARDINAL> 163</CARDINAL></SPAT>
# F1-Score : 1.0
#
# Billand, r. du Faub.-Montmartre, 11.
# <PER>Billand</PER>,<SPAT><LOC> r. du Faub.-Montmartre</LOC>,<CARDINAL> 11</CARDINAL></SPAT>.
# F1-Score : 1.0
#
# Bernard, Enfer, 124
# <PER>Bernard</PER>,<SPAT><LOC> Enfer</LOC>,<CARDINAL> 124</CARDINAL></SPAT>
# F1-Score : 1.0
#
# Lecomte, aven. de Lowendal, 51
# <PER>Lecomte</PER>,<SPAT><LOC> aven. de Lowendal</LOC>,<CARDINAL> 51</CARDINAL></SPAT>
# F1-Score : 1.0
#
# Auberville (Ctesse d') , Grenelle-Saint-Ger-main, 100.
# <PER>Auberville (Ctesse d')</PER> ,<SPAT><LOC> Grenelle-Saint-Ger-main</LOC>,<CARDINAL> 100</CARDINAL></SPAT>.
# F1-Score : 1.0

# %% [markdown]
# ## Sub-word global analysis

# %%
flat_preds = []
flat_labels = []
for i in range(len(df)):
    flat_preds += df["tags_preds"][i]
    flat_labels += df["tags_gold"][i]
flat_preds = pd.Series(flat_preds, name="Predictions")
flat_labels = pd.Series(flat_labels, name="Gold")

global_confusion = pd.crosstab(flat_labels, flat_preds,normalize='index').multiply(100., axis=1)
global_confusion.columns = ["ACT+O","DESC+O","DESC+ACT","DESC+TITREP","PER+O","PER+TITREH","SPAT+O","SPAT+CARD","SPAT+FT","SPAT+LOC","O+O"]
global_confusion.index = ["ACT+O","DESC+O","DESC+ACT","DESC+TITREP","PER+O","PER+TITREH","SPAT+O","SPAT+CARD","SPAT+FT","SPAT+LOC","O+O"]
global_confusion
# Out:
#                  ACT+O     DESC+O   DESC+ACT  DESC+TITREP      PER+O  \
# ACT+O        89.796765   5.226047   3.131481     0.000000   0.580672
# DESC+O       15.425940  44.973139  34.919417     0.690714   1.841903
# DESC+ACT     19.205298   9.492274  71.302428     0.000000   0.000000
# DESC+TITREP   0.000000  38.495575   4.424779    57.079646   0.000000
# PER+O         0.567802   0.434202   0.000000     0.000000  98.046092
# PER+TITREH    0.000000   0.000000   0.000000     0.000000   1.333333
# SPAT+O        0.000000   0.380022   0.000000     0.000000   0.000000
# SPAT+CARD     0.000000   0.000000   0.000000     0.000000   0.000000
# SPAT+FT      17.777778  31.111111   0.000000     0.000000   0.000000
# SPAT+LOC      0.123693   0.179917   0.000000     0.000000   0.101203
# O+O          43.551609   2.042175   1.886792     0.332963   5.948946
#
#              PER+TITREH     SPAT+O  SPAT+CARD    SPAT+FT   SPAT+LOC        O+O
# ACT+O          0.000000   0.041477   0.000000   0.041477   0.788055   0.394027
# DESC+O         0.000000   0.000000   0.000000   0.000000   1.688411   0.460476
# DESC+ACT       0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# DESC+TITREP    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# PER+O          0.033400   0.016700   0.016700   0.000000   0.200401   0.684703
# PER+TITREH    86.666667   0.000000   0.000000   0.000000   0.000000  12.000000
# SPAT+O         0.000000  95.114007   1.248643   0.000000   1.845820   1.411509
# SPAT+CARD      0.000000   0.382514  98.306011   0.000000   0.273224   1.038251
# SPAT+FT        0.000000   2.222222   4.444444  24.444444   0.000000  20.000000
# SPAT+LOC       0.000000   0.337344   0.033734   0.000000  99.055437   0.168672
# O+O            0.221976   0.288568   2.463929   0.000000  17.380688  25.882353

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Init figure
plt.figure(figsize=(34, 16))

#Create heatmap
snsfig = sns.heatmap(
    global_confusion, 
    annot = True, #Display labels
    cmap=sns.color_palette("rocket_r", as_cmap=True), #Color
    fmt=".1f",
    cbar=False,
    annot_kws={"fontsize":40}
)

#Rename label axis and set their style
plt.xlabel('Predictions',weight = 'bold',fontsize=35) # x-axis label with fontsize 15
plt.ylabel('Gold',weight = 'bold',fontsize=35) # y-axis label with fontsize 15

#Set x labels position to top
snsfig.xaxis.tick_top()
snsfig.xaxis.set_label_position('top')

#Rotate y ticks horizontaly
plt.yticks(rotation=0) 

#Change ticks size
snsfig.set_xticklabels(snsfig.get_xmajorticklabels(), fontsize = 32)
snsfig.set_yticklabels(snsfig.get_ymajorticklabels(), fontsize = 32)

print("Confusion matrix of reference and predicted tokens types.")
print("Values are normalized by row (percentage of each reference classe and its resultants predictions)")
print("Last row represent percentage of each class in gold.")

plt.show()

#Save figure
fig = snsfig.get_figure()
fig.tight_layout()
#fig.savefig(f"./tokenscaleanalysis-{FORMAT}-{SET}.pdf")
# Out:
# Confusion matrix of reference and predicted tokens types.
# Values are normalized by row (percentage of each reference classe and its resultants predictions)
# Last row represent percentage of each class in gold.

# %% [markdown]
# ## Entry scale analysis

# %% [markdown]
# Please choose one entry giving its index to perform an entry scale analysis :

# %%
i = 5

# %%
print(df.iloc[i]["entry"])
print(df.iloc[i]["entry_xml"])
# Out:
# FiRion (H,pla ce des complVictoiresgétoff es
# <PER>FiRion (H,</PER><ACT>pla ce</ACT><SPAT><LOC> des complVictoiresgétoff</LOC></SPAT> es

# %%
from seqeval.metrics import classification_report

y_preds = df.iloc[i]["tags_preds"]
y_true = df.iloc[i]["tags_gold"]
print(classification_report([y_true],[y_preds]))
# Out:
#               precision    recall  f1-score   support
#
#        ACT+O       0.00      0.00      0.00         1
#        PER+O       0.00      0.00      0.00         1
#   SPAT+i_LOC       0.00      0.00      0.00         1
#
#    micro avg       0.00      0.00      0.00         3
#    macro avg       0.00      0.00      0.00         3
# weighted avg       0.00      0.00      0.00         3
# /lrde/home2/stual/.venv/python_3_9/lib/python3.10/site-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: O+O seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

y_true = pd.Series(df["tags_gold"].iloc[i], name='Gold')
y_pred = pd.Series(df["tags_preds"].iloc[i], name='Predictions')
entry_confusion = pd.crosstab(y_true, y_pred)
entry_confusion
# Out:
# Predictions   I-ACT+O  I-PER+O  I-SPAT+i_LOC  O+O
# Gold
# I-ACT+O             0        0             1    0
# I-PER+O             2        6             0    0
# I-SPAT+i_LOC        0        0             3    0
# O+O                 0        0             3    1

# %%
plt.figure(figsize=(8, 6))

#Create heatmap
snsfig = sns.heatmap(
    entry_confusion, 
    annot = True, #Display labels
    cmap=sns.color_palette("rocket_r", as_cmap=True), #Color
    fmt="g",
    cbar=False,
    annot_kws={"fontsize":30}
)

#Rename label axis and set their style
plt.xlabel('Predictions',weight = 'bold',fontsize=25) # x-axis label with fontsize 15
plt.ylabel('Gold',weight = 'bold',fontsize=25) # y-axis label with fontsize 15

#Set x labels position to top
snsfig.xaxis.tick_top()
snsfig.xaxis.set_label_position('top')

#Rotate y ticks horizontaly
plt.yticks(rotation=0) 

#Change ticks size
snsfig.set_xticklabels(snsfig.get_xmajorticklabels(), fontsize = 20)
snsfig.set_yticklabels(snsfig.get_ymajorticklabels(), fontsize = 20)

print("Confusion matrix of reference and predicted tokens types.")

plt.show()

#Save figure
fig = snsfig.get_figure()
# Out:
# Confusion matrix of reference and predicted tokens types.
